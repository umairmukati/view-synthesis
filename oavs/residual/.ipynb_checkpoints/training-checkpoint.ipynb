# %% [markdown]
# #### IMPORT LIBRARIES

# %%
import numpy as np
import h5py as h5

import torch
from torchvision import datasets, transforms
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
from importlib import reload, import_module

import glob
import os

import pdb
from PIL import Image as im
import _pickle as pickle


from functions import MyDataset, customTransform, get_variable, get_numpy, compute_gradient, psnr_1

# %% [markdown]
# #### DATASET PATH

# %%
if os.name == 'nt':
    dataset_file = r"C:\Users\mummu\Documents\Datasets\srinivasan\trainset\h5\8bit.h5"
    test_file    = r"C:\Users\mummu\Documents\Datasets\srinivasan\testset\h5\8bit.h5"
    model_file   = r"model\model.pt"
    network_file = r"network"
    trainwr_file = r"runs\train"
    testwr_file  = r"runs\test"
elif os.name == 'posix':
    raise NotImplementedError

# %% [markdown]
# #### BASIC PARAMETERS

# %%
patch_size     = 192
batch_size     = 300
minibatch_size = 5
gamma_val      = 0.4
lfsize         = [372, 540, 7, 7]
num_workers    = 0
num_test       = 10
num_minibatch  = batch_size//minibatch_size
batch_affine   = True
num_epochs     = 10000

# %% [markdown]
# #### INITIALIZE FUNCTIONS

# %%
data_transform = transforms.Compose([transforms.ToTensor(), 
                                     transforms.Lambda(customTransform)])

train_dataset  = MyDataset(dataset_file, lfsize, data_transform)
test_dataset   = MyDataset(test_file, lfsize, data_transform)

train_loader   = torch.utils.data.DataLoader(train_dataset, batch_size=minibatch_size, num_workers=num_workers, shuffle=True)
test_loader    = torch.utils.data.DataLoader(train_dataset, batch_size=minibatch_size, num_workers=num_workers, shuffle=True)

# %% [markdown]
# #### LOOKING FOR SAVED MODEL

# %%
network_module = import_module(network_file)
reload(network_module)
Net = network_module.Net

net = Net((patch_size, patch_size), minibatch_size, lfsize, batchAffine=batch_affine)
if torch.cuda.is_available():
    print('##converting network to cuda-enabled')
    net.cuda()

try:
    checkpoint = torch.load(model_file)
    
    epoch_id = checkpoint['epoch']
    #net.load_state_dict(checkpoint['model'].state_dict())
    net.load_my_state_dict(checkpoint['model'].state_dict())
    print('Model successfully loaded.')
    
    for name, param in net.named_parameters():
        if not name.startswith('r_'):
            param.requires_grad = False
    
    for name, param in net.named_parameters():
        print(name, param.requires_grad)
    
except:
    print('No model.')
    epoch_id = 0
# Out:
# ##converting network to cuda-enabled
# Model successfully loaded.
# beta False
# f_conv0.weight False
# f_conv1.weight False
# f_conv2.weight False
# f_conv3.weight False
# f_conv4.weight False
# f_conv5.weight False
# f_bn0.weight False
# f_bn0.bias False
# f_bn1.weight False
# f_bn1.bias False
# f_bn2.weight False
# f_bn2.bias False
# f_bn3.weight False
# f_bn3.bias False
# f_bn4.weight False
# f_bn4.bias False
# f_bn5.weight False
# f_bn5.bias False
# d_conv0.weight False
# d_conv1.weight False
# d_conv2.weight False
# d_conv3.weight False
# d_conv4.weight False
# d_conv5.weight False
# d_conv6.weight False
# d_bn0.weight False
# d_bn0.bias False
# d_bn1.weight False
# d_bn1.bias False
# d_bn2.weight False
# d_bn2.bias False
# d_bn3.weight False
# d_bn3.bias False
# d_bn4.weight False
# d_bn4.bias False
# d_bn5.weight False
# d_bn5.bias False
# s_conv0.weight False
# s_conv1.weight False
# s_conv2.weight False
# s_conv3.weight False
# s_conv4.weight False
# s_conv5.weight False
# s_conv6.weight False
# s_bn0.weight False
# s_bn0.bias False
# s_bn1.weight False
# s_bn1.bias False
# s_bn2.weight False
# s_bn2.bias False
# s_bn3.weight False
# s_bn3.bias False
# s_bn4.weight False
# s_bn4.bias False
# s_bn5.weight False
# s_bn5.bias False
# r_conv0.weight True
# r_conv1.weight True
# r_conv2.weight True
# r_conv3.weight True
# r_conv4.weight True
# r_conv5.weight True
# r_conv6.weight True
# r_bn0.weight True
# r_bn0.bias True
# r_bn1.weight True
# r_bn1.bias True
# r_bn2.weight True
# r_bn2.bias True
# r_bn3.weight True
# r_bn3.bias True
# r_bn4.weight True
# r_bn4.bias True
# r_bn5.weight True
# r_bn5.bias True

# %% [markdown]
# #### TRAINING SETTINGS

# %%
criterion1 = nn.L1Loss()
criterion2 = nn.L1Loss()
optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999))

# %%
def train_epoch():
    costs = []
            
    for batch_num in range(num_minibatch):
        
        # fetching training batch
        corners, pers, ind = next(iter(train_loader))
        
        # converting to trainable variables
        X_corners = get_variable(corners)
        T_view = get_variable(pers)
        p = get_variable(ind[:,0])
        q = get_variable(ind[:,-1])
                
        optimizer.zero_grad()
        
        # Forward pass
        I, R = net(X_corners, p, q)
        T = (I - T_view)/2
        
        # Computing batch loss
        batch_loss = criterion1(T, R)
        
        # Backpropagation
        batch_loss.backward()
        optimizer.step()

        # recording performance
        costs.append(get_numpy(batch_loss))
    
        
    return np.mean(costs)

def eval_epoch():
    costs = []
    
    for batch_num in range(num_test):
        
        # fetching training batch
        corners, pers, ind = next(iter(test_loader))
        
        # converting to trainable variables
        X_corners = get_variable(corners)
        T_view = get_variable(pers)
        p = get_variable(ind[:,0])
        q = get_variable(ind[:,-1])

        with torch.no_grad():
            # Forward pass
            I, R = net(X_corners, p, q)
            T = (I - T_view)/2
            
            # Computing batch loss
            batch_loss = criterion1(T, R)
            
            # recording performance
            costs.append(get_numpy(batch_loss))

    return np.mean(costs)

# %%
valid_accs, train_accs, test_accs = [], [], []

writer_train = SummaryWriter(trainwr_file)
writer_test  = SummaryWriter(testwr_file)

while epoch_id < num_epochs:
    epoch_id += 1
    
    try:   
        net.train()
        train_cost = train_epoch()
        
        net.eval()
        test_cost = eval_epoch()
        
        print("Epoch %d:" % epoch_id)     
        print("Epoch {0:0}, train_cost {1:.2}".format(epoch_id, train_cost))
        
        writer_train.add_scalar('loss', train_cost, epoch_id)
        writer_test.add_scalar('loss', test_cost, epoch_id)
        
        torch.save({'model': net, 'epoch': epoch_id}, model_file)
    
    except KeyboardInterrupt:
        print('\nKeyboardInterrupt')
        break
# Out:
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\nn\functional.py:2404: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Epoch 1:
# Epoch 1, train_cost 0.027
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type AvgPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch 2:
# Epoch 2, train_cost 0.016
# Epoch 3:
# Epoch 3, train_cost 0.016
# Epoch 4:
# Epoch 4, train_cost 0.017
# Epoch 5:
# Epoch 5, train_cost 0.015
# Epoch 6:
# Epoch 6, train_cost 0.015
# Epoch 7:
# Epoch 7, train_cost 0.015
# Epoch 8:
# Epoch 8, train_cost 0.016
# Epoch 9:
# Epoch 9, train_cost 0.015
# Epoch 10:
# Epoch 10, train_cost 0.015
# Epoch 11:
# Epoch 11, train_cost 0.015
# Epoch 12:
# Epoch 12, train_cost 0.014
# Epoch 13:
# Epoch 13, train_cost 0.014
# Epoch 14:
# Epoch 14, train_cost 0.015
# Epoch 15:
# Epoch 15, train_cost 0.014
# Epoch 16:
# Epoch 16, train_cost 0.014
# Epoch 17:
# Epoch 17, train_cost 0.014
# Epoch 18:
# Epoch 18, train_cost 0.015
# Epoch 19:
# Epoch 19, train_cost 0.016
# Epoch 20:
# Epoch 20, train_cost 0.015
# Epoch 21:
# Epoch 21, train_cost 0.014
# Epoch 22:
# Epoch 22, train_cost 0.015
# Epoch 23:
# Epoch 23, train_cost 0.014
# Epoch 24:
# Epoch 24, train_cost 0.015
# Epoch 25:
# Epoch 25, train_cost 0.014
# Epoch 26:
# Epoch 26, train_cost 0.014
# Epoch 27:
# Epoch 27, train_cost 0.015
# Epoch 28:
# Epoch 28, train_cost 0.015
# Epoch 29:
# Epoch 29, train_cost 0.015
# Epoch 30:
# Epoch 30, train_cost 0.015
# Epoch 31:
# Epoch 31, train_cost 0.014
# Epoch 32:
# Epoch 32, train_cost 0.015
# Epoch 33:
# Epoch 33, train_cost 0.014
# Epoch 34:
# Epoch 34, train_cost 0.015
# Epoch 35:
# Epoch 35, train_cost 0.014
# Epoch 36:
# Epoch 36, train_cost 0.014
# Epoch 37:
# Epoch 37, train_cost 0.014
# Epoch 38:
# Epoch 38, train_cost 0.015
# Epoch 39:
# Epoch 39, train_cost 0.014
# Epoch 40:
# Epoch 40, train_cost 0.015
# Epoch 41:
# Epoch 41, train_cost 0.029
# Epoch 42:
# Epoch 42, train_cost 0.018
# Epoch 43:
# Epoch 43, train_cost 0.014
# Epoch 44:
# Epoch 44, train_cost 0.014
# Epoch 45:
# Epoch 45, train_cost 0.015
# Epoch 46:
# Epoch 46, train_cost 0.015
# Epoch 47:
# Epoch 47, train_cost 0.014
# Epoch 48:
# Epoch 48, train_cost 0.015
# Epoch 49:
# Epoch 49, train_cost 0.015
# Epoch 50:
# Epoch 50, train_cost 0.014
# Epoch 51:
# Epoch 51, train_cost 0.015
# Epoch 52:
# Epoch 52, train_cost 0.014
# Epoch 53:
# Epoch 53, train_cost 0.015
# Epoch 54:
# Epoch 54, train_cost 0.015
# Epoch 55:
# Epoch 55, train_cost 0.014
# Epoch 56:
# Epoch 56, train_cost 0.015
# Epoch 57:
# Epoch 57, train_cost 0.014
# Epoch 58:
# Epoch 58, train_cost 0.015
# Epoch 59:
# Epoch 59, train_cost 0.015
# Epoch 60:
# Epoch 60, train_cost 0.014
# Epoch 61:
# Epoch 61, train_cost 0.014
# Epoch 62:
# Epoch 62, train_cost 0.014
# Epoch 63:
# Epoch 63, train_cost 0.014
# Epoch 64:
# Epoch 64, train_cost 0.014
# Epoch 65:
# Epoch 65, train_cost 0.014
# Epoch 66:
# Epoch 66, train_cost 0.015
# Epoch 67:
# Epoch 67, train_cost 0.014
# Epoch 68:
# Epoch 68, train_cost 0.014
# Epoch 69:
# Epoch 69, train_cost 0.015
# Epoch 70:
# Epoch 70, train_cost 0.015
# Epoch 71:
# Epoch 71, train_cost 0.015
# Epoch 72:
# Epoch 72, train_cost 0.014
# Epoch 73:
# Epoch 73, train_cost 0.015
# Epoch 74:
# Epoch 74, train_cost 0.015
# Epoch 75:
# Epoch 75, train_cost 0.014
# Epoch 76:
# Epoch 76, train_cost 0.014
# Epoch 77:
# Epoch 77, train_cost 0.014
# Epoch 78:
# Epoch 78, train_cost 0.014
# Epoch 79:
# Epoch 79, train_cost 0.015
# Epoch 80:
# Epoch 80, train_cost 0.015
# Epoch 81:
# Epoch 81, train_cost 0.014
# Epoch 82:
# Epoch 82, train_cost 0.014
# Epoch 83:
# Epoch 83, train_cost 0.015
# Epoch 84:
# Epoch 84, train_cost 0.014
# Epoch 85:
# Epoch 85, train_cost 0.015
# Epoch 86:
# Epoch 86, train_cost 0.014
# Epoch 87:
# Epoch 87, train_cost 0.015
# Epoch 88:
# Epoch 88, train_cost 0.015
# Epoch 89:
# Epoch 89, train_cost 0.014
# Epoch 90:
# Epoch 90, train_cost 0.014
# Epoch 91:
# Epoch 91, train_cost 0.015
# Epoch 92:
# Epoch 92, train_cost 0.014
# Epoch 93:
# Epoch 93, train_cost 0.015
# Epoch 94:
# Epoch 94, train_cost 0.015
# Epoch 95:
# Epoch 95, train_cost 0.014
# Epoch 96:
# Epoch 96, train_cost 0.015
# Epoch 97:
# Epoch 97, train_cost 0.014
# Epoch 98:
# Epoch 98, train_cost 0.014
# Epoch 99:
# Epoch 99, train_cost 0.014
# Epoch 100:
# Epoch 100, train_cost 0.015
# Epoch 101:
# Epoch 101, train_cost 0.014
# Epoch 102:
# Epoch 102, train_cost 0.015
# Epoch 103:
# Epoch 103, train_cost 0.015
# Epoch 104:
# Epoch 104, train_cost 0.014
# Epoch 105:
# Epoch 105, train_cost 0.018
# Epoch 106:
# Epoch 106, train_cost 0.016
# Epoch 107:
# Epoch 107, train_cost 0.014
# Epoch 108:
# Epoch 108, train_cost 0.015
# Epoch 109:
# Epoch 109, train_cost 0.015
# Epoch 110:
# Epoch 110, train_cost 0.016
# Epoch 111:
# Epoch 111, train_cost 0.015
# Epoch 112:
# Epoch 112, train_cost 0.015
# Epoch 113:
# Epoch 113, train_cost 0.015
# Epoch 114:
# Epoch 114, train_cost 0.014
# Epoch 115:
# Epoch 115, train_cost 0.015
# Epoch 116:
# Epoch 116, train_cost 0.015
# Epoch 117:
# Epoch 117, train_cost 0.015
# Epoch 118:
# Epoch 118, train_cost 0.015
#
# KeyboardInterrupt
