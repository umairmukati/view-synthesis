# %% [markdown]
# #### IMPORT LIBRARIES

# %%
import numpy as np
import h5py as h5

import torch
from torchvision import datasets, transforms
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
from importlib import reload, import_module

import glob
import os

import pdb
from PIL import Image as im
import _pickle as pickle


from functions import MyDataset, customTransform, get_variable, get_numpy, compute_gradient, psnr_1

# %% [markdown]
# #### DATASET PATH

# %%
if os.name == 'nt':
    dataset_file = r"C:\Users\mummu\Documents\Datasets\srinivasan\trainset\h5\8bit.h5"
    test_file    = r"C:\Users\mummu\Documents\Datasets\srinivasan\testset\h5\8bit.h5"
    model_file   = r"model\model.pt"
    network_file = r"network"
    trainwr_file = r"runs\train"
    testwr_file  = r"runs\test"
elif os.name == 'posix':
    raise NotImplementedError

# %% [markdown]
# #### BASIC PARAMETERS

# %%
patch_size     = 192
batch_size     = 300
minibatch_size = 5
gamma_val      = 0.4
lfsize         = [372, 540, 7, 7]
num_workers    = 0
num_test       = 10
num_minibatch  = batch_size//minibatch_size
batch_affine   = True
num_epochs     = 10000

# %% [markdown]
# #### INITIALIZE FUNCTIONS

# %%
data_transform = transforms.Compose([transforms.ToTensor(), 
                                     transforms.Lambda(customTransform)])

train_dataset  = MyDataset(dataset_file, lfsize, data_transform)
test_dataset   = MyDataset(test_file, lfsize, data_transform)

train_loader   = torch.utils.data.DataLoader(train_dataset, batch_size=minibatch_size, num_workers=num_workers, shuffle=True)
test_loader    = torch.utils.data.DataLoader(train_dataset, batch_size=minibatch_size, num_workers=num_workers, shuffle=True)

# %% [markdown]
# #### LOOKING FOR SAVED MODEL

# %%
network_module = import_module(network_file)
reload(network_module)
Net = network_module.Net

net = Net((patch_size, patch_size), minibatch_size, lfsize, batchAffine=batch_affine)
if torch.cuda.is_available():
    print('##converting network to cuda-enabled')
    net.cuda()

try:
    checkpoint = torch.load(model_file)
    
    epoch_id = checkpoint['epoch']
    #net.load_state_dict(checkpoint['model'].state_dict())
    net.load_my_state_dict(checkpoint['model'].state_dict())
    print('Model successfully loaded.')
    
    for name, param in net.named_parameters():
        if not name.startswith('r_'):
            param.requires_grad = False
    
    for name, param in net.named_parameters():
        print(name, param.requires_grad)
    
except:
    print('No model.')
    epoch_id = 0
# Out:
# ##converting network to cuda-enabled
# Model successfully loaded.
# beta False
# f_conv0.weight False
# f_conv1.weight False
# f_conv2.weight False
# f_conv3.weight False
# f_conv4.weight False
# f_conv5.weight False
# f_bn0.weight False
# f_bn0.bias False
# f_bn1.weight False
# f_bn1.bias False
# f_bn2.weight False
# f_bn2.bias False
# f_bn3.weight False
# f_bn3.bias False
# f_bn4.weight False
# f_bn4.bias False
# f_bn5.weight False
# f_bn5.bias False
# d_conv0.weight False
# d_conv1.weight False
# d_conv2.weight False
# d_conv3.weight False
# d_conv4.weight False
# d_conv5.weight False
# d_conv6.weight False
# d_bn0.weight False
# d_bn0.bias False
# d_bn1.weight False
# d_bn1.bias False
# d_bn2.weight False
# d_bn2.bias False
# d_bn3.weight False
# d_bn3.bias False
# d_bn4.weight False
# d_bn4.bias False
# d_bn5.weight False
# d_bn5.bias False
# s_conv0.weight False
# s_conv1.weight False
# s_conv2.weight False
# s_conv3.weight False
# s_conv4.weight False
# s_conv5.weight False
# s_conv6.weight False
# s_bn0.weight False
# s_bn0.bias False
# s_bn1.weight False
# s_bn1.bias False
# s_bn2.weight False
# s_bn2.bias False
# s_bn3.weight False
# s_bn3.bias False
# s_bn4.weight False
# s_bn4.bias False
# s_bn5.weight False
# s_bn5.bias False
# r_conv0.weight True
# r_conv1.weight True
# r_conv2.weight True
# r_conv3.weight True
# r_conv4.weight True
# r_conv5.weight True
# r_conv6.weight True
# r_bn0.weight True
# r_bn0.bias True
# r_bn1.weight True
# r_bn1.bias True
# r_bn2.weight True
# r_bn2.bias True
# r_bn3.weight True
# r_bn3.bias True
# r_bn4.weight True
# r_bn4.bias True
# r_bn5.weight True
# r_bn5.bias True

# %% [markdown]
# #### TRAINING SETTINGS

# %%
criterion1 = nn.L1Loss()
criterion2 = nn.L1Loss()
optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999))

# %%
def train_epoch():
    costs = []
            
    for batch_num in range(num_minibatch):
        
        # fetching training batch
        corners, pers, ind = next(iter(train_loader))
        
        # converting to trainable variables
        X_corners = get_variable(corners)
        T_view = get_variable(pers)
        p = get_variable(ind[:,0])
        q = get_variable(ind[:,-1])
                
        optimizer.zero_grad()
        
        # Forward pass
        I, R = net(X_corners, p, q)
        T = (I - T_view)/2
        
        # Computing batch loss
        batch_loss = criterion1(T, R)
        
        # Backpropagation
        batch_loss.backward()
        optimizer.step()

        # recording performance
        costs.append(get_numpy(batch_loss))
    
        
    return np.mean(costs)

def eval_epoch():
    costs = []
    
    for batch_num in range(num_test):
        
        # fetching training batch
        corners, pers, ind = next(iter(test_loader))
        
        # converting to trainable variables
        X_corners = get_variable(corners)
        T_view = get_variable(pers)
        p = get_variable(ind[:,0])
        q = get_variable(ind[:,-1])

        with torch.no_grad():
            # Forward pass
            I, R = net(X_corners, p, q)
            T = (I - T_view)/2
            
            # Computing batch loss
            batch_loss = criterion1(T, R)
            
            # recording performance
            costs.append(get_numpy(batch_loss))

    return np.mean(costs)

# %%
valid_accs, train_accs, test_accs = [], [], []

writer_train = SummaryWriter(trainwr_file)
writer_test  = SummaryWriter(testwr_file)

while epoch_id < num_epochs:
    epoch_id += 1
    
    try:   
        net.train()
        train_cost = train_epoch()
        
        net.eval()
        test_cost = eval_epoch()
        
        print("Epoch %d:" % epoch_id)     
        print("Epoch {0:0}, train_cost {1:.2}".format(epoch_id, train_cost))
        
        writer_train.add_scalar('loss', train_cost, epoch_id)
        writer_test.add_scalar('loss', test_cost, epoch_id)
        
        torch.save({'model': net, 'epoch': epoch_id}, model_file)
    
    except KeyboardInterrupt:
        print('\nKeyboardInterrupt')
        break
# Out:
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\nn\functional.py:2404: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Epoch 216:
# Epoch 216, train_cost 0.0072
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type AvgPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch 217:
# Epoch 217, train_cost 0.0075
# Epoch 218:
# Epoch 218, train_cost 0.0072
# Epoch 219:
# Epoch 219, train_cost 0.0072
# Epoch 220:
# Epoch 220, train_cost 0.0074
# Epoch 221:
# Epoch 221, train_cost 0.0071
# Epoch 222:
# Epoch 222, train_cost 0.0072
# Epoch 223:
# Epoch 223, train_cost 0.007
# Epoch 224:
# Epoch 224, train_cost 0.0066
# Epoch 225:
# Epoch 225, train_cost 0.0072
# Epoch 226:
# Epoch 226, train_cost 0.0069
# Epoch 227:
# Epoch 227, train_cost 0.0071
# Epoch 228:
# Epoch 228, train_cost 0.0071
# Epoch 229:
# Epoch 229, train_cost 0.0074
# Epoch 230:
# Epoch 230, train_cost 0.0074
# Epoch 231:
# Epoch 231, train_cost 0.0074
# Epoch 232:
# Epoch 232, train_cost 0.0071
# Epoch 233:
# Epoch 233, train_cost 0.0067
# Epoch 234:
# Epoch 234, train_cost 0.007
# Epoch 235:
# Epoch 235, train_cost 0.0075
# Epoch 236:
# Epoch 236, train_cost 0.0069
# Epoch 237:
# Epoch 237, train_cost 0.0072
# Epoch 238:
# Epoch 238, train_cost 0.0071
# Epoch 239:
# Epoch 239, train_cost 0.0067
# Epoch 240:
# Epoch 240, train_cost 0.0071
# Epoch 241:
# Epoch 241, train_cost 0.0073
# Epoch 242:
# Epoch 242, train_cost 0.0071
# Epoch 243:
# Epoch 243, train_cost 0.007
# Epoch 244:
# Epoch 244, train_cost 0.0071
# Epoch 245:
# Epoch 245, train_cost 0.0074
# Epoch 246:
# Epoch 246, train_cost 0.0071
# Epoch 247:
# Epoch 247, train_cost 0.0072
# Epoch 248:
# Epoch 248, train_cost 0.0071
# Epoch 249:
# Epoch 249, train_cost 0.0074
# Epoch 250:
# Epoch 250, train_cost 0.007
# Epoch 251:
# Epoch 251, train_cost 0.007
# Epoch 252:
# Epoch 252, train_cost 0.0071
# Epoch 253:
# Epoch 253, train_cost 0.007
# Epoch 254:
# Epoch 254, train_cost 0.0071
# Epoch 255:
# Epoch 255, train_cost 0.0071
# Epoch 256:
# Epoch 256, train_cost 0.0073
# Epoch 257:
# Epoch 257, train_cost 0.0071
# Epoch 258:
# Epoch 258, train_cost 0.007
# Epoch 259:
# Epoch 259, train_cost 0.0071
# Epoch 260:
# Epoch 260, train_cost 0.0071
# Epoch 261:
# Epoch 261, train_cost 0.0068
# Epoch 262:
# Epoch 262, train_cost 0.0072
# Epoch 263:
# Epoch 263, train_cost 0.0069
# Epoch 264:
# Epoch 264, train_cost 0.0069
# Epoch 265:
# Epoch 265, train_cost 0.0072
# Epoch 266:
# Epoch 266, train_cost 0.0072
# Epoch 267:
# Epoch 267, train_cost 0.0069
# Epoch 268:
# Epoch 268, train_cost 0.0072
# Epoch 269:
# Epoch 269, train_cost 0.007
# Epoch 270:
# Epoch 270, train_cost 0.0071
# Epoch 271:
# Epoch 271, train_cost 0.0068
# Epoch 272:
# Epoch 272, train_cost 0.0072
# Epoch 273:
# Epoch 273, train_cost 0.007
# Epoch 274:
# Epoch 274, train_cost 0.0066
# Epoch 275:
# Epoch 275, train_cost 0.0069
# Epoch 276:
# Epoch 276, train_cost 0.0071
# Epoch 277:
# Epoch 277, train_cost 0.0067
# Epoch 278:
# Epoch 278, train_cost 0.0068
# Epoch 279:
# Epoch 279, train_cost 0.0071
# Epoch 280:
# Epoch 280, train_cost 0.0071
# Epoch 281:
# Epoch 281, train_cost 0.0069
# Epoch 282:
# Epoch 282, train_cost 0.0068
# Epoch 283:
# Epoch 283, train_cost 0.0071
# Epoch 284:
# Epoch 284, train_cost 0.0068
# Epoch 285:
# Epoch 285, train_cost 0.0075
# Epoch 286:
# Epoch 286, train_cost 0.007
# Epoch 287:
# Epoch 287, train_cost 0.0071
# Epoch 288:
# Epoch 288, train_cost 0.007
# Epoch 289:
# Epoch 289, train_cost 0.0071
# Epoch 290:
# Epoch 290, train_cost 0.007
# Epoch 291:
# Epoch 291, train_cost 0.0074
# Epoch 292:
# Epoch 292, train_cost 0.0072
# Epoch 293:
# Epoch 293, train_cost 0.0073
# Epoch 294:
# Epoch 294, train_cost 0.0069
# Epoch 295:
# Epoch 295, train_cost 0.0069
# Epoch 296:
# Epoch 296, train_cost 0.0069
# Epoch 297:
# Epoch 297, train_cost 0.0074
# Epoch 298:
# Epoch 298, train_cost 0.0069
# Epoch 299:
# Epoch 299, train_cost 0.0072
# Epoch 300:
# Epoch 300, train_cost 0.0071
# Epoch 301:
# Epoch 301, train_cost 0.0072
# Epoch 302:
# Epoch 302, train_cost 0.0067
# Epoch 303:
# Epoch 303, train_cost 0.0069
# Epoch 304:
# Epoch 304, train_cost 0.0071
# Epoch 305:
# Epoch 305, train_cost 0.0069
# Epoch 306:
# Epoch 306, train_cost 0.0068
# Epoch 307:
# Epoch 307, train_cost 0.0071
# Epoch 308:
# Epoch 308, train_cost 0.0067
# Epoch 309:
# Epoch 309, train_cost 0.0071
# Epoch 310:
# Epoch 310, train_cost 0.0076
# Epoch 311:
# Epoch 311, train_cost 0.0073
# Epoch 312:
# Epoch 312, train_cost 0.007
# Epoch 313:
# Epoch 313, train_cost 0.0071
# Epoch 314:
# Epoch 314, train_cost 0.0072
# Epoch 315:
# Epoch 315, train_cost 0.0072
# Epoch 316:
# Epoch 316, train_cost 0.0071
# Epoch 317:
# Epoch 317, train_cost 0.0072
# Epoch 318:
# Epoch 318, train_cost 0.007
# Epoch 319:
# Epoch 319, train_cost 0.0071
# Epoch 320:
# Epoch 320, train_cost 0.007
# Epoch 321:
# Epoch 321, train_cost 0.0067
# Epoch 322:
# Epoch 322, train_cost 0.0071
# Epoch 323:
# Epoch 323, train_cost 0.007
# Epoch 324:
# Epoch 324, train_cost 0.0069
# Epoch 325:
# Epoch 325, train_cost 0.0071
# Epoch 326:
# Epoch 326, train_cost 0.0069
# Epoch 327:
# Epoch 327, train_cost 0.0073
# Epoch 328:
# Epoch 328, train_cost 0.0072
# Epoch 329:
# Epoch 329, train_cost 0.0074
# Epoch 330:
# Epoch 330, train_cost 0.0069
# Epoch 331:
# Epoch 331, train_cost 0.0072
# Epoch 332:
# Epoch 332, train_cost 0.0071
# Epoch 333:
# Epoch 333, train_cost 0.0065
# Epoch 334:
# Epoch 334, train_cost 0.0072
# Epoch 335:
# Epoch 335, train_cost 0.007
# Epoch 336:
# Epoch 336, train_cost 0.0069
# Epoch 337:
# Epoch 337, train_cost 0.007
# Epoch 338:
# Epoch 338, train_cost 0.0068
# Epoch 339:
# Epoch 339, train_cost 0.0071
# Epoch 340:
# Epoch 340, train_cost 0.0073
# Epoch 341:
# Epoch 341, train_cost 0.0072
# Epoch 342:
# Epoch 342, train_cost 0.007
# Epoch 343:
# Epoch 343, train_cost 0.007
# Epoch 344:
# Epoch 344, train_cost 0.007
# Epoch 345:
# Epoch 345, train_cost 0.0072
# Epoch 346:
# Epoch 346, train_cost 0.007
# Epoch 347:
# Epoch 347, train_cost 0.0071
# Epoch 348:
# Epoch 348, train_cost 0.0071
# Epoch 349:
# Epoch 349, train_cost 0.007
# Epoch 350:
# Epoch 350, train_cost 0.0069
# Epoch 351:
# Epoch 351, train_cost 0.0072
# Epoch 352:
# Epoch 352, train_cost 0.0074
# Epoch 353:
# Epoch 353, train_cost 0.007
# Epoch 354:
# Epoch 354, train_cost 0.007
# Epoch 355:
# Epoch 355, train_cost 0.0069
# Epoch 356:
# Epoch 356, train_cost 0.007
