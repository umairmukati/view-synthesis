# %% [markdown]
# #### IMPORT LIBRARIES

# %%
import numpy as np
import h5py as h5

import torch
from torchvision import datasets, transforms
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
from importlib import reload, import_module

import glob
import os

import pdb
from PIL import Image as im
import _pickle as pickle


from functions import MyDataset, customTransform, get_variable, get_numpy, compute_gradient, psnr_1, count_parameters

# %% [markdown]
# #### DATASET PATH

# %%
if os.name == 'nt':
    dataset_file = r"C:\Users\mummu\Documents\Datasets\srinivasan\trainset\h5\8bit.h5"
    test_file    = r"C:\Users\mummu\Documents\Datasets\srinivasan\testset\h5\8bit.h5"
    model_file   = r"model\model.pt"
    network_file = r"network_train"
    trainwr_file = r"runs\train"
    testwr_file  = r"runs\test"
elif os.name == 'posix':
    raise NotImplementedError

# %% [markdown]
# #### BASIC PARAMETERS

# %%
patch_size     = 192
batch_size     = 300
minibatch_size = 3
gamma_val      = 0.4
lfsize         = [372, 540, 7, 7]
num_workers    = 0
num_test       = 10
num_minibatch  = batch_size//minibatch_size
batch_affine   = True
num_epochs     = 10000

# %% [markdown]
# #### INITIALIZE FUNCTIONS

# %%
data_transform = transforms.Compose([transforms.ToTensor(), 
                                     transforms.Lambda(customTransform)])

train_dataset  = MyDataset(dataset_file, lfsize, data_transform)
test_dataset   = MyDataset(test_file, lfsize, data_transform)

train_loader   = torch.utils.data.DataLoader(train_dataset, batch_size=minibatch_size, num_workers=num_workers, shuffle=True)
test_loader    = torch.utils.data.DataLoader(train_dataset, batch_size=minibatch_size, num_workers=num_workers, shuffle=True)

# %% [markdown]
# #### LOOKING FOR SAVED MODEL

# %%
network_module = import_module(network_file)
reload(network_module)
Net = network_module.Net

net = Net((patch_size, patch_size), minibatch_size, lfsize, batchAffine=batch_affine)
if torch.cuda.is_available():
    print('##converting network to cuda-enabled')
    net.cuda()

try:
    checkpoint = torch.load(model_file)
    
    epoch_id = checkpoint['epoch']
    net.load_state_dict(checkpoint['model'].state_dict())
    print('Model successfully loaded.')
    
except:
    print('No model.')
    epoch_id = 0
# Out:
# ##converting network to cuda-enabled
# Model successfully loaded.

# %% [markdown]
# #### TRAINING SETTINGS

# %%
criterion1 = nn.L1Loss()
criterion2 = nn.L1Loss()
criterion3 = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999))

# %%
def train_epoch():
    costs = []
    psnr_vec = []
            
    for batch_num in range(num_minibatch):
        
        # fetching training batch
        corners, pers, ind = next(iter(train_loader))
        
        # converting to trainable variables
        X_corners = get_variable(corners)
        T_view = get_variable(pers)
        p = get_variable(ind[:,0])
        q = get_variable(ind[:,-1])
                
        optimizer.zero_grad()
        
        # Forward pass
        O_view, M = net(X_corners, p, q)
        
        # Computing batch loss
        batch_loss = criterion1(O_view, T_view) + .5*criterion2(compute_gradient(O_view), compute_gradient(T_view)) \
                    + 0.5*((M.reshape(-1,12).mean(0))**2).sum()
        
        # Backpropagation
        batch_loss.backward()
        optimizer.step()

        # recording performance
        costs.append(get_numpy(batch_loss))
        net_out = get_numpy(O_view)
        Y = get_numpy(T_view)      
        psnr_vec.append([psnr_1(np.squeeze(net_out[i]), np.squeeze(Y[i])) for i in range(minibatch_size)])
    
        
    return np.mean(costs), np.mean(psnr_vec)

def eval_epoch():
    costs = []
    psnr_vec = []
    
    for batch_num in range(num_test):
        
        # fetching training batch
        corners, pers, ind = next(iter(test_loader))
        
        # converting to trainable variables
        X_corners = get_variable(corners)
        T_view = get_variable(pers)
        p = get_variable(ind[:,0])
        q = get_variable(ind[:,-1])

        with torch.no_grad():
            # Forward pass
            O_view, M = net(X_corners, p, q)
            
            # Computing batch loss
            batch_loss = criterion1(O_view, T_view) + .5*criterion2(compute_gradient(O_view), compute_gradient(T_view))\
                    + 0.5*((M.reshape(-1,12).mean(0))**2).sum()
            
            # recording performance
            costs.append(get_numpy(batch_loss))
            net_out = get_numpy(O_view)
            Y = get_numpy(T_view)
            psnr_vec.append([psnr_1(np.squeeze(net_out[i]), np.squeeze(Y[i])) for i in range(minibatch_size)])

    return np.mean(costs), np.mean(psnr_vec)

# %%
valid_accs, train_accs, test_accs = [], [], []

writer_train = SummaryWriter(trainwr_file)
writer_test  = SummaryWriter(testwr_file)

while epoch_id < num_epochs:
    epoch_id += 1
    
    try:   
        net.train()
        train_cost, train_psnr = train_epoch()
        
        net.eval()
        test_cost, test_psnr = eval_epoch()
        
        print("Epoch %d:" % epoch_id)     
        print("Epoch {0:0}, train_cost {1:.2}, psnr {2:.2}".format(epoch_id, train_cost, train_psnr))
        
        writer_train.add_scalar('psnr', train_psnr, epoch_id)
        writer_train.add_scalar('loss', train_cost, epoch_id)
        writer_test.add_scalar('psnr', test_psnr, epoch_id)
        writer_test.add_scalar('loss', test_cost, epoch_id)
        
        torch.save({'model': net, 'epoch': epoch_id}, model_file)
    
    except KeyboardInterrupt:
        print('\nKeyboardInterrupt')
        break
# Out:
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\nn\functional.py:2404: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Epoch 2821:
# Epoch 2821, train_cost 0.085, psnr 4e+01
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type AvgPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\mummu\AppData\Local\Continuum\anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch 2822:
# Epoch 2822, train_cost 0.084, psnr 4e+01
# Epoch 2823:
# Epoch 2823, train_cost 0.082, psnr 4e+01
# Epoch 2824:
# Epoch 2824, train_cost 0.084, psnr 4e+01
# Epoch 2825:
# Epoch 2825, train_cost 0.083, psnr 4e+01
# Epoch 2826:
# Epoch 2826, train_cost 0.086, psnr 4e+01
# Epoch 2827:
# Epoch 2827, train_cost 0.083, psnr 4e+01
# Epoch 2828:
# Epoch 2828, train_cost 0.082, psnr 4e+01
# Epoch 2829:
# Epoch 2829, train_cost 0.082, psnr 4e+01
# Epoch 2830:
# Epoch 2830, train_cost 0.082, psnr 4e+01
# Epoch 2831:
# Epoch 2831, train_cost 0.081, psnr 4e+01
# Epoch 2832:
# Epoch 2832, train_cost 0.081, psnr 4e+01
# Epoch 2833:
# Epoch 2833, train_cost 0.084, psnr 4e+01
# Epoch 2834:
# Epoch 2834, train_cost 0.086, psnr 4e+01
# Epoch 2835:
# Epoch 2835, train_cost 0.082, psnr 4e+01
# Epoch 2836:
# Epoch 2836, train_cost 0.081, psnr 4e+01
# Epoch 2962:
# Epoch 2962, train_cost 0.082, psnr 4e+01
# Epoch 2963:
# Epoch 2963, train_cost 0.083, psnr 4e+01
# Epoch 2964:
# Epoch 2964, train_cost 0.083, psnr 4e+01
# Epoch 2965:
# Epoch 2965, train_cost 0.081, psnr 4e+01
# Epoch 2966:
# Epoch 2966, train_cost 0.084, psnr 4e+01
# Epoch 2967:
# Epoch 2967, train_cost 0.081, psnr 4e+01
# Epoch 2968:
# Epoch 2968, train_cost 0.081, psnr 4e+01
# Epoch 2969:
# Epoch 2969, train_cost 0.081, psnr 4e+01
# Epoch 2970:
# Epoch 2970, train_cost 0.081, psnr 4.1e+01
# Epoch 2971:
# Epoch 2971, train_cost 0.083, psnr 4e+01
# Epoch 2972:
# Epoch 2972, train_cost 0.083, psnr 4e+01
# Epoch 2973:
# Epoch 2973, train_cost 0.081, psnr 4e+01
# Epoch 2974:
# Epoch 2974, train_cost 0.082, psnr 4e+01
# Epoch 2975:
# Epoch 2975, train_cost 0.083, psnr 4e+01
# Epoch 2976:
# Epoch 2976, train_cost 0.084, psnr 4e+01
# Epoch 2977:
# Epoch 2977, train_cost 0.082, psnr 4e+01
# Epoch 2978:
# Epoch 2978, train_cost 0.084, psnr 4e+01
# Epoch 2979:
# Epoch 2979, train_cost 0.083, psnr 4e+01
# Epoch 2980:
# Epoch 2980, train_cost 0.081, psnr 4e+01
# Epoch 2981:
# Epoch 2981, train_cost 0.084, psnr 4e+01
# Epoch 2982:
# Epoch 2982, train_cost 0.081, psnr 4e+01
# Epoch 2983:
# Epoch 2983, train_cost 0.083, psnr 4e+01
# Epoch 2984:
# Epoch 2984, train_cost 0.085, psnr 4e+01
# Epoch 2985:
# Epoch 2985, train_cost 0.083, psnr 4e+01
# Epoch 2986:
# Epoch 2986, train_cost 0.081, psnr 4.1e+01
# Epoch 2987:
# Epoch 2987, train_cost 0.082, psnr 4e+01
# Epoch 2988:
# Epoch 2988, train_cost 0.084, psnr 4e+01
# Epoch 2989:
# Epoch 2989, train_cost 0.083, psnr 4e+01
# Epoch 2990:
# Epoch 2990, train_cost 0.084, psnr 4e+01
# Epoch 2991:
# Epoch 2991, train_cost 0.08, psnr 4e+01
# Epoch 2992:
# Epoch 2992, train_cost 0.083, psnr 4e+01
# Epoch 2993:
# Epoch 2993, train_cost 0.084, psnr 4e+01
# Epoch 2994:
# Epoch 2994, train_cost 0.081, psnr 4.1e+01
# Epoch 2995:
# Epoch 2995, train_cost 0.082, psnr 4e+01
# Epoch 2996:
# Epoch 2996, train_cost 0.083, psnr 4e+01
# Epoch 2997:
# Epoch 2997, train_cost 0.085, psnr 4e+01
# Epoch 2998:
# Epoch 2998, train_cost 0.083, psnr 4e+01
# Epoch 2999:
# Epoch 2999, train_cost 0.081, psnr 4e+01
# Epoch 3000:
# Epoch 3000, train_cost 0.083, psnr 4e+01
# Epoch 3001:
# Epoch 3001, train_cost 0.082, psnr 4e+01
# Epoch 3002:
# Epoch 3002, train_cost 0.083, psnr 4e+01
# Epoch 3003:
# Epoch 3003, train_cost 0.081, psnr 4e+01
# Epoch 3004:
# Epoch 3004, train_cost 0.082, psnr 4e+01
# Epoch 3005:
# Epoch 3005, train_cost 0.083, psnr 4e+01
# Epoch 3006:
# Epoch 3006, train_cost 0.081, psnr 4e+01
# Epoch 3007:
# Epoch 3007, train_cost 0.083, psnr 4e+01
# Epoch 3008:
# Epoch 3008, train_cost 0.083, psnr 4e+01
# Epoch 3009:
# Epoch 3009, train_cost 0.081, psnr 4e+01
# Epoch 3010:
# Epoch 3010, train_cost 0.082, psnr 4e+01
# Epoch 3011:
# Epoch 3011, train_cost 0.083, psnr 4e+01
# Epoch 3012:
# Epoch 3012, train_cost 0.084, psnr 4e+01
# Epoch 3013:
# Epoch 3013, train_cost 0.081, psnr 4e+01
# Epoch 3014:
# Epoch 3014, train_cost 0.084, psnr 4e+01
# Epoch 3015:
# Epoch 3015, train_cost 0.081, psnr 4e+01
# Epoch 3016:
# Epoch 3016, train_cost 0.085, psnr 4e+01
# Epoch 3017:
# Epoch 3017, train_cost 0.083, psnr 4e+01
# Epoch 3018:
# Epoch 3018, train_cost 0.082, psnr 4e+01
# Epoch 3019:
# Epoch 3019, train_cost 0.081, psnr 4e+01
# Epoch 3020:
# Epoch 3020, train_cost 0.082, psnr 4e+01
# Epoch 3021:
# Epoch 3021, train_cost 0.081, psnr 4e+01
# Epoch 3022:
# Epoch 3022, train_cost 0.083, psnr 4e+01
# Epoch 3023:
# Epoch 3023, train_cost 0.084, psnr 4e+01
# Epoch 3024:
# Epoch 3024, train_cost 0.082, psnr 4e+01
# Epoch 3025:
# Epoch 3025, train_cost 0.082, psnr 4e+01
# Epoch 3026:
# Epoch 3026, train_cost 0.083, psnr 4e+01
# Epoch 3027:
# Epoch 3027, train_cost 0.082, psnr 4e+01
# Epoch 3028:
# Epoch 3028, train_cost 0.084, psnr 4e+01
# Epoch 3029:
# Epoch 3029, train_cost 0.084, psnr 4e+01
# Epoch 3030:
# Epoch 3030, train_cost 0.082, psnr 4e+01
# Epoch 3031:
# Epoch 3031, train_cost 0.082, psnr 4e+01
# Epoch 3032:
# Epoch 3032, train_cost 0.085, psnr 4e+01
# Epoch 3033:
# Epoch 3033, train_cost 0.083, psnr 4e+01
# Epoch 3034:
# Epoch 3034, train_cost 0.082, psnr 4e+01
# Epoch 3035:
# Epoch 3035, train_cost 0.084, psnr 4e+01
# Epoch 3036:
# Epoch 3036, train_cost 0.083, psnr 4e+01
# Epoch 3037:
# Epoch 3037, train_cost 0.085, psnr 4e+01
# Epoch 3038:
# Epoch 3038, train_cost 0.083, psnr 4e+01
# Epoch 3039:
# Epoch 3039, train_cost 0.081, psnr 4e+01
# Epoch 3040:
# Epoch 3040, train_cost 0.082, psnr 4e+01
# Epoch 3041:
# Epoch 3041, train_cost 0.083, psnr 4e+01
# Epoch 3042:
# Epoch 3042, train_cost 0.08, psnr 4e+01
# Epoch 3043:
# Epoch 3043, train_cost 0.08, psnr 4e+01
# Epoch 3044:
# Epoch 3044, train_cost 0.082, psnr 4e+01
# Epoch 3045:
# Epoch 3045, train_cost 0.082, psnr 4e+01
# Epoch 3046:
# Epoch 3046, train_cost 0.084, psnr 4e+01
# Epoch 3047:
# Epoch 3047, train_cost 0.082, psnr 4e+01
# Epoch 3048:
# Epoch 3048, train_cost 0.081, psnr 4e+01
# Epoch 3049:
# Epoch 3049, train_cost 0.082, psnr 4e+01
# Epoch 3050:
# Epoch 3050, train_cost 0.084, psnr 4e+01
# Epoch 3051:
# Epoch 3051, train_cost 0.082, psnr 4e+01
# Epoch 3052:
# Epoch 3052, train_cost 0.081, psnr 4e+01
# Epoch 3053:
# Epoch 3053, train_cost 0.082, psnr 4e+01
# Epoch 3054:
# Epoch 3054, train_cost 0.083, psnr 4e+01
# Epoch 3055:
# Epoch 3055, train_cost 0.083, psnr 4e+01
# Epoch 3056:
# Epoch 3056, train_cost 0.083, psnr 4e+01
# Epoch 3057:
# Epoch 3057, train_cost 0.083, psnr 4e+01
# Epoch 3058:
# Epoch 3058, train_cost 0.083, psnr 4e+01
# Epoch 3059:
# Epoch 3059, train_cost 0.08, psnr 4e+01
# Epoch 3060:
# Epoch 3060, train_cost 0.082, psnr 4e+01
# Epoch 3061:
# Epoch 3061, train_cost 0.083, psnr 4e+01
# Epoch 3062:
# Epoch 3062, train_cost 0.082, psnr 4e+01
# Epoch 3063:
# Epoch 3063, train_cost 0.083, psnr 4e+01
# Epoch 3064:
# Epoch 3064, train_cost 0.083, psnr 4e+01
# Epoch 3065:
# Epoch 3065, train_cost 0.082, psnr 4e+01
# Epoch 3066:
# Epoch 3066, train_cost 0.082, psnr 4e+01
# Epoch 3067:
# Epoch 3067, train_cost 0.084, psnr 4e+01
# Epoch 3068:
# Epoch 3068, train_cost 0.081, psnr 4e+01
# Epoch 3069:
# Epoch 3069, train_cost 0.082, psnr 4e+01
# Epoch 3070:
# Epoch 3070, train_cost 0.082, psnr 4e+01
# Epoch 3071:
# Epoch 3071, train_cost 0.081, psnr 4e+01
# Epoch 3072:
# Epoch 3072, train_cost 0.082, psnr 4e+01
# Epoch 3073:
# Epoch 3073, train_cost 0.084, psnr 4e+01
# Epoch 3074:
# Epoch 3074, train_cost 0.082, psnr 4e+01
# Epoch 3075:
# Epoch 3075, train_cost 0.082, psnr 4e+01
# Epoch 3076:
# Epoch 3076, train_cost 0.081, psnr 4e+01
# Epoch 3077:
# Epoch 3077, train_cost 0.085, psnr 4e+01
# Epoch 3078:
# Epoch 3078, train_cost 0.082, psnr 4e+01
# Epoch 3079:
# Epoch 3079, train_cost 0.083, psnr 4e+01
# Epoch 3080:
# Epoch 3080, train_cost 0.085, psnr 4e+01
# Epoch 3081:
# Epoch 3081, train_cost 0.082, psnr 4e+01
# Epoch 3082:
# Epoch 3082, train_cost 0.083, psnr 4e+01
# Epoch 3083:
# Epoch 3083, train_cost 0.085, psnr 4e+01
# Epoch 3084:
# Epoch 3084, train_cost 0.083, psnr 4e+01
# Epoch 3085:
# Epoch 3085, train_cost 0.081, psnr 4e+01
# Epoch 3086:
# Epoch 3086, train_cost 0.085, psnr 4e+01
# Epoch 3087:
# Epoch 3087, train_cost 0.082, psnr 4e+01
# Epoch 3088:
# Epoch 3088, train_cost 0.082, psnr 4e+01
# Epoch 3089:
# Epoch 3089, train_cost 0.082, psnr 4e+01
# Epoch 3090:
# Epoch 3090, train_cost 0.085, psnr 4e+01
# Epoch 3091:
# Epoch 3091, train_cost 0.083, psnr 4e+01
# Epoch 3092:
# Epoch 3092, train_cost 0.084, psnr 4e+01
# Epoch 3093:
# Epoch 3093, train_cost 0.081, psnr 4e+01
# Epoch 3094:
# Epoch 3094, train_cost 0.086, psnr 4e+01
# Epoch 3095:
# Epoch 3095, train_cost 0.079, psnr 4.1e+01
# Epoch 3096:
# Epoch 3096, train_cost 0.081, psnr 4e+01
# Epoch 3097:
# Epoch 3097, train_cost 0.083, psnr 4e+01
# Epoch 3098:
# Epoch 3098, train_cost 0.08, psnr 4.1e+01
# Epoch 3099:
# Epoch 3099, train_cost 0.083, psnr 4e+01
# Epoch 3100:
# Epoch 3100, train_cost 0.082, psnr 4e+01
# Epoch 3101:
# Epoch 3101, train_cost 0.085, psnr 4e+01
# Epoch 3102:
# Epoch 3102, train_cost 0.081, psnr 4e+01
# Epoch 3103:
# Epoch 3103, train_cost 0.081, psnr 4e+01
# Epoch 3104:
# Epoch 3104, train_cost 0.085, psnr 4e+01
# Epoch 3105:
# Epoch 3105, train_cost 0.082, psnr 4e+01
# Epoch 3106:
# Epoch 3106, train_cost 0.084, psnr 4e+01
# Epoch 3107:
# Epoch 3107, train_cost 0.083, psnr 4e+01
# Epoch 3108:
# Epoch 3108, train_cost 0.084, psnr 4e+01
# Epoch 3109:
# Epoch 3109, train_cost 0.081, psnr 4e+01
# Epoch 3110:
# Epoch 3110, train_cost 0.081, psnr 4e+01
# Epoch 3111:
# Epoch 3111, train_cost 0.083, psnr 4e+01
# Epoch 3112:
# Epoch 3112, train_cost 0.081, psnr 4e+01
# Epoch 3113:
# Epoch 3113, train_cost 0.084, psnr 4e+01
# Epoch 3114:
# Epoch 3114, train_cost 0.082, psnr 4e+01
# Epoch 3115:
# Epoch 3115, train_cost 0.083, psnr 4e+01
# Epoch 3116:
# Epoch 3116, train_cost 0.081, psnr 4e+01
# Epoch 3117:
# Epoch 3117, train_cost 0.084, psnr 4e+01
# Epoch 3118:
# Epoch 3118, train_cost 0.082, psnr 4e+01
# Epoch 3119:
# Epoch 3119, train_cost 0.085, psnr 4e+01
# Epoch 3120:
# Epoch 3120, train_cost 0.081, psnr 4e+01
# Epoch 3121:
# Epoch 3121, train_cost 0.084, psnr 4e+01
# Epoch 3122:
# Epoch 3122, train_cost 0.084, psnr 4e+01
# Epoch 3123:
# Epoch 3123, train_cost 0.084, psnr 4e+01
# Epoch 3124:
# Epoch 3124, train_cost 0.08, psnr 4.1e+01
# Epoch 3125:
# Epoch 3125, train_cost 0.08, psnr 4.1e+01
# Epoch 3126:
# Epoch 3126, train_cost 0.084, psnr 4e+01
# Epoch 3127:
# Epoch 3127, train_cost 0.083, psnr 4e+01
# Epoch 3128:
# Epoch 3128, train_cost 0.083, psnr 4e+01
# Epoch 3129:
# Epoch 3129, train_cost 0.082, psnr 4e+01
# Epoch 3130:
# Epoch 3130, train_cost 0.082, psnr 4e+01
# Epoch 3131:
# Epoch 3131, train_cost 0.084, psnr 4e+01
# Epoch 3132:
# Epoch 3132, train_cost 0.083, psnr 4e+01
# Epoch 3133:
# Epoch 3133, train_cost 0.08, psnr 4.1e+01
# Epoch 3134:
# Epoch 3134, train_cost 0.082, psnr 4e+01
# Epoch 3135:
# Epoch 3135, train_cost 0.083, psnr 4e+01
# Epoch 3136:
# Epoch 3136, train_cost 0.079, psnr 4.1e+01
# Epoch 3137:
# Epoch 3137, train_cost 0.085, psnr 4e+01
# Epoch 3138:
# Epoch 3138, train_cost 0.083, psnr 4e+01
# Epoch 3139:
# Epoch 3139, train_cost 0.082, psnr 4e+01
# Epoch 3140:
# Epoch 3140, train_cost 0.082, psnr 4e+01
# Epoch 3141:
# Epoch 3141, train_cost 0.084, psnr 4e+01
# Epoch 3142:
# Epoch 3142, train_cost 0.081, psnr 4e+01
# Epoch 3143:
# Epoch 3143, train_cost 0.081, psnr 4e+01
# Epoch 3144:
# Epoch 3144, train_cost 0.083, psnr 4e+01
# Epoch 3145:
# Epoch 3145, train_cost 0.083, psnr 4e+01
# Epoch 3146:
# Epoch 3146, train_cost 0.082, psnr 4e+01
# Epoch 3147:
# Epoch 3147, train_cost 0.082, psnr 4e+01
# Epoch 3148:
# Epoch 3148, train_cost 0.08, psnr 4.1e+01
# Epoch 3149:
# Epoch 3149, train_cost 0.085, psnr 4e+01
# Epoch 3150:
# Epoch 3150, train_cost 0.08, psnr 4e+01
# Epoch 3151:
# Epoch 3151, train_cost 0.085, psnr 4e+01
# Epoch 3152:
# Epoch 3152, train_cost 0.082, psnr 4e+01
# Epoch 3153:
# Epoch 3153, train_cost 0.08, psnr 4e+01
# Epoch 3154:
# Epoch 3154, train_cost 0.083, psnr 4e+01
# Epoch 3155:
# Epoch 3155, train_cost 0.083, psnr 4e+01
# Epoch 3156:
# Epoch 3156, train_cost 0.083, psnr 4e+01
# Epoch 3157:
# Epoch 3157, train_cost 0.084, psnr 4e+01
# Epoch 3158:
# Epoch 3158, train_cost 0.082, psnr 4e+01
# Epoch 3159:
# Epoch 3159, train_cost 0.083, psnr 4e+01
# Epoch 3160:
# Epoch 3160, train_cost 0.079, psnr 4.1e+01
# Epoch 3161:
# Epoch 3161, train_cost 0.081, psnr 4e+01
# Epoch 3162:
# Epoch 3162, train_cost 0.083, psnr 4e+01
# Epoch 3163:
# Epoch 3163, train_cost 0.083, psnr 4e+01
# Epoch 3164:
# Epoch 3164, train_cost 0.084, psnr 4e+01
# Epoch 3165:
# Epoch 3165, train_cost 0.084, psnr 4e+01
# Epoch 3166:
# Epoch 3166, train_cost 0.082, psnr 4e+01
# Epoch 3167:
# Epoch 3167, train_cost 0.082, psnr 4e+01
# Epoch 3168:
# Epoch 3168, train_cost 0.083, psnr 4e+01
# Epoch 3169:
# Epoch 3169, train_cost 0.082, psnr 4e+01
# Epoch 3170:
# Epoch 3170, train_cost 0.081, psnr 4e+01
# Epoch 3171:
# Epoch 3171, train_cost 0.083, psnr 4e+01
# Epoch 3172:
# Epoch 3172, train_cost 0.082, psnr 4e+01
# Epoch 3173:
# Epoch 3173, train_cost 0.08, psnr 4.1e+01
# Epoch 3174:
# Epoch 3174, train_cost 0.083, psnr 4e+01
# Epoch 3175:
# Epoch 3175, train_cost 0.083, psnr 4e+01
# Epoch 3176:
# Epoch 3176, train_cost 0.083, psnr 4e+01
# Epoch 3177:
# Epoch 3177, train_cost 0.081, psnr 4e+01
# Epoch 3178:
# Epoch 3178, train_cost 0.084, psnr 4e+01
# Epoch 3179:
# Epoch 3179, train_cost 0.081, psnr 4e+01
# Epoch 3180:
# Epoch 3180, train_cost 0.082, psnr 4e+01
# Epoch 3181:
# Epoch 3181, train_cost 0.084, psnr 4e+01
# Epoch 3182:
# Epoch 3182, train_cost 0.083, psnr 4e+01
# Epoch 3183:
# Epoch 3183, train_cost 0.085, psnr 4e+01
# Epoch 3184:
# Epoch 3184, train_cost 0.081, psnr 4e+01
# Epoch 3185:
# Epoch 3185, train_cost 0.084, psnr 4e+01
# Epoch 3186:
# Epoch 3186, train_cost 0.081, psnr 4e+01
# Epoch 3187:
# Epoch 3187, train_cost 0.082, psnr 4e+01
# Epoch 3188:
# Epoch 3188, train_cost 0.082, psnr 4e+01
# Epoch 3189:
# Epoch 3189, train_cost 0.08, psnr 4.1e+01
# Epoch 3190:
# Epoch 3190, train_cost 0.082, psnr 4e+01
# Epoch 3191:
# Epoch 3191, train_cost 0.083, psnr 4e+01
# Epoch 3192:
# Epoch 3192, train_cost 0.082, psnr 4e+01
# Epoch 3193:
# Epoch 3193, train_cost 0.081, psnr 4e+01
# Epoch 3194:
# Epoch 3194, train_cost 0.083, psnr 4e+01
# Epoch 3195:
# Epoch 3195, train_cost 0.083, psnr 4e+01
# Epoch 3196:
# Epoch 3196, train_cost 0.083, psnr 4e+01
# Epoch 3197:
# Epoch 3197, train_cost 0.084, psnr 4e+01
# Epoch 3198:
# Epoch 3198, train_cost 0.083, psnr 4e+01
# Epoch 3199:
# Epoch 3199, train_cost 0.081, psnr 4e+01
# Epoch 3200:
# Epoch 3200, train_cost 0.084, psnr 4e+01
# Epoch 3201:
# Epoch 3201, train_cost 0.083, psnr 4e+01
# Epoch 3202:
# Epoch 3202, train_cost 0.081, psnr 4e+01
# Epoch 3203:
# Epoch 3203, train_cost 0.081, psnr 4e+01
# Epoch 3204:
# Epoch 3204, train_cost 0.085, psnr 4e+01
# Epoch 3205:
# Epoch 3205, train_cost 0.083, psnr 4e+01
# Epoch 3206:
# Epoch 3206, train_cost 0.081, psnr 4e+01
# Epoch 3207:
# Epoch 3207, train_cost 0.083, psnr 4e+01
# Epoch 3208:
# Epoch 3208, train_cost 0.081, psnr 4e+01
# Epoch 3209:
# Epoch 3209, train_cost 0.084, psnr 4e+01
# Epoch 3210:
# Epoch 3210, train_cost 0.08, psnr 4.1e+01
# Epoch 3211:
# Epoch 3211, train_cost 0.082, psnr 4e+01
# Epoch 3212:
# Epoch 3212, train_cost 0.082, psnr 4e+01
# Epoch 3213:
# Epoch 3213, train_cost 0.081, psnr 4e+01
# Epoch 3214:
# Epoch 3214, train_cost 0.084, psnr 4e+01
# Epoch 3215:
# Epoch 3215, train_cost 0.081, psnr 4.1e+01
# Epoch 3216:
# Epoch 3216, train_cost 0.084, psnr 4e+01
# Epoch 3217:
# Epoch 3217, train_cost 0.082, psnr 4e+01
# Epoch 3218:
# Epoch 3218, train_cost 0.084, psnr 4e+01
# Epoch 3219:
# Epoch 3219, train_cost 0.082, psnr 4e+01
# Epoch 3220:
# Epoch 3220, train_cost 0.083, psnr 4e+01
# Epoch 3221:
# Epoch 3221, train_cost 0.081, psnr 4e+01
# Epoch 3222:
# Epoch 3222, train_cost 0.081, psnr 4e+01
# Epoch 3223:
# Epoch 3223, train_cost 0.082, psnr 4e+01
# Epoch 3224:
# Epoch 3224, train_cost 0.083, psnr 4e+01
# Epoch 3225:
# Epoch 3225, train_cost 0.082, psnr 4e+01
# Epoch 3226:
# Epoch 3226, train_cost 0.083, psnr 4e+01
# Epoch 3227:
# Epoch 3227, train_cost 0.084, psnr 4e+01
# Epoch 3228:
# Epoch 3228, train_cost 0.081, psnr 4e+01
# Epoch 3229:
# Epoch 3229, train_cost 0.082, psnr 4e+01
# Epoch 3230:
# Epoch 3230, train_cost 0.084, psnr 4e+01
# Epoch 3231:
# Epoch 3231, train_cost 0.083, psnr 4e+01
# Epoch 3232:
# Epoch 3232, train_cost 0.082, psnr 4e+01
# Epoch 3233:
# Epoch 3233, train_cost 0.081, psnr 4e+01
# Epoch 3234:
# Epoch 3234, train_cost 0.082, psnr 4e+01
# Epoch 3235:
# Epoch 3235, train_cost 0.083, psnr 4e+01
# Epoch 3236:
# Epoch 3236, train_cost 0.084, psnr 4e+01
# Epoch 3237:
# Epoch 3237, train_cost 0.082, psnr 4e+01
# Epoch 3238:
# Epoch 3238, train_cost 0.081, psnr 4e+01
# Epoch 3239:
# Epoch 3239, train_cost 0.081, psnr 4e+01
# Epoch 3240:
# Epoch 3240, train_cost 0.085, psnr 4e+01
# Epoch 3241:
# Epoch 3241, train_cost 0.082, psnr 4e+01
# Epoch 3242:
# Epoch 3242, train_cost 0.082, psnr 4e+01
# Epoch 3243:
# Epoch 3243, train_cost 0.082, psnr 4e+01
# Epoch 3244:
# Epoch 3244, train_cost 0.08, psnr 4.1e+01
# Epoch 3245:
# Epoch 3245, train_cost 0.081, psnr 4.1e+01
# Epoch 3246:
# Epoch 3246, train_cost 0.083, psnr 4e+01
# Epoch 3247:
# Epoch 3247, train_cost 0.081, psnr 4e+01
# Epoch 3248:
# Epoch 3248, train_cost 0.08, psnr 4e+01
# Epoch 3249:
# Epoch 3249, train_cost 0.083, psnr 4e+01
# Epoch 3250:
# Epoch 3250, train_cost 0.083, psnr 4e+01
# Epoch 3251:
# Epoch 3251, train_cost 0.081, psnr 4e+01
# Epoch 3252:
# Epoch 3252, train_cost 0.08, psnr 4e+01
# Epoch 3253:
# Epoch 3253, train_cost 0.085, psnr 4e+01
# Epoch 3254:
# Epoch 3254, train_cost 0.081, psnr 4e+01
# Epoch 3255:
# Epoch 3255, train_cost 0.083, psnr 4e+01
# Epoch 3256:
# Epoch 3256, train_cost 0.083, psnr 4e+01
# Epoch 3257:
# Epoch 3257, train_cost 0.082, psnr 4e+01
# Epoch 3258:
# Epoch 3258, train_cost 0.081, psnr 4e+01
# Epoch 3259:
# Epoch 3259, train_cost 0.081, psnr 4e+01
# Epoch 3260:
# Epoch 3260, train_cost 0.085, psnr 4e+01
# Epoch 3261:
# Epoch 3261, train_cost 0.084, psnr 4e+01
# Epoch 3262:
# Epoch 3262, train_cost 0.084, psnr 4e+01
# Epoch 3263:
# Epoch 3263, train_cost 0.083, psnr 4e+01
# Epoch 3264:
# Epoch 3264, train_cost 0.083, psnr 4e+01
# Epoch 3265:
# Epoch 3265, train_cost 0.084, psnr 4e+01
# Epoch 3266:
# Epoch 3266, train_cost 0.08, psnr 4e+01
# Epoch 3267:
# Epoch 3267, train_cost 0.082, psnr 4e+01
# Epoch 3268:
# Epoch 3268, train_cost 0.084, psnr 4e+01
# Epoch 3269:
# Epoch 3269, train_cost 0.082, psnr 4e+01
# Epoch 3270:
# Epoch 3270, train_cost 0.082, psnr 4e+01
# Epoch 3271:
# Epoch 3271, train_cost 0.084, psnr 4e+01
# Epoch 3272:
# Epoch 3272, train_cost 0.082, psnr 4e+01
# Epoch 3273:
# Epoch 3273, train_cost 0.084, psnr 4e+01
# Epoch 3274:
# Epoch 3274, train_cost 0.082, psnr 4e+01
# Epoch 3275:
# Epoch 3275, train_cost 0.08, psnr 4.1e+01
# Epoch 3276:
# Epoch 3276, train_cost 0.08, psnr 4.1e+01
# Epoch 3277:
# Epoch 3277, train_cost 0.082, psnr 4e+01
# Epoch 3278:
# Epoch 3278, train_cost 0.083, psnr 4e+01
# Epoch 3279:
# Epoch 3279, train_cost 0.083, psnr 4e+01
# Epoch 3280:
# Epoch 3280, train_cost 0.081, psnr 4.1e+01
# Epoch 3281:
# Epoch 3281, train_cost 0.083, psnr 4e+01
# Epoch 3282:
# Epoch 3282, train_cost 0.085, psnr 4e+01
# Epoch 3283:
# Epoch 3283, train_cost 0.083, psnr 4e+01
# Epoch 3284:
# Epoch 3284, train_cost 0.082, psnr 4e+01
# Epoch 3285:
# Epoch 3285, train_cost 0.083, psnr 4e+01
# Epoch 3286:
# Epoch 3286, train_cost 0.082, psnr 4e+01
# Epoch 3287:
# Epoch 3287, train_cost 0.084, psnr 4e+01
# Epoch 3288:
# Epoch 3288, train_cost 0.082, psnr 4e+01
# Epoch 3289:
# Epoch 3289, train_cost 0.083, psnr 4e+01
# Epoch 3290:
# Epoch 3290, train_cost 0.082, psnr 4e+01
# Epoch 3291:
# Epoch 3291, train_cost 0.08, psnr 4.1e+01
# Epoch 3292:
# Epoch 3292, train_cost 0.083, psnr 4e+01
# Epoch 3293:
# Epoch 3293, train_cost 0.084, psnr 4e+01
# Epoch 3294:
# Epoch 3294, train_cost 0.082, psnr 4e+01
# Epoch 3295:
# Epoch 3295, train_cost 0.083, psnr 4e+01
# Epoch 3296:
# Epoch 3296, train_cost 0.082, psnr 4e+01
# Epoch 3297:
# Epoch 3297, train_cost 0.083, psnr 4e+01
# Epoch 3298:
# Epoch 3298, train_cost 0.083, psnr 4e+01
# Epoch 3299:
# Epoch 3299, train_cost 0.083, psnr 4e+01
# Epoch 3300:
# Epoch 3300, train_cost 0.085, psnr 4e+01
# Epoch 3301:
# Epoch 3301, train_cost 0.084, psnr 4e+01
# Epoch 3302:
# Epoch 3302, train_cost 0.083, psnr 4e+01
# Epoch 3303:
# Epoch 3303, train_cost 0.082, psnr 4e+01
# Epoch 3304:
# Epoch 3304, train_cost 0.081, psnr 4e+01
# Epoch 3305:
# Epoch 3305, train_cost 0.081, psnr 4e+01
# Epoch 3306:
# Epoch 3306, train_cost 0.082, psnr 4e+01
# Epoch 3307:
# Epoch 3307, train_cost 0.083, psnr 4e+01
# Epoch 3308:
# Epoch 3308, train_cost 0.083, psnr 4e+01
# Epoch 3309:
# Epoch 3309, train_cost 0.083, psnr 4e+01
# Epoch 3310:
# Epoch 3310, train_cost 0.084, psnr 4e+01
# Epoch 3311:
# Epoch 3311, train_cost 0.083, psnr 4e+01
# Epoch 3312:
# Epoch 3312, train_cost 0.083, psnr 4e+01
# Epoch 3313:
# Epoch 3313, train_cost 0.082, psnr 4e+01
# Epoch 3314:
# Epoch 3314, train_cost 0.084, psnr 4e+01
# Epoch 3315:
# Epoch 3315, train_cost 0.082, psnr 4e+01
# Epoch 3316:
# Epoch 3316, train_cost 0.084, psnr 4e+01
# Epoch 3317:
# Epoch 3317, train_cost 0.082, psnr 4e+01
# Epoch 3318:
# Epoch 3318, train_cost 0.083, psnr 4e+01
# Epoch 3319:
# Epoch 3319, train_cost 0.085, psnr 4e+01
# Epoch 3320:
# Epoch 3320, train_cost 0.082, psnr 4e+01
# Epoch 3321:
# Epoch 3321, train_cost 0.083, psnr 4e+01
# Epoch 3322:
# Epoch 3322, train_cost 0.083, psnr 4e+01
# Epoch 3323:
# Epoch 3323, train_cost 0.083, psnr 4e+01
# Epoch 3324:
# Epoch 3324, train_cost 0.083, psnr 4e+01
# Epoch 3325:
# Epoch 3325, train_cost 0.082, psnr 4e+01
# Epoch 3326:
# Epoch 3326, train_cost 0.083, psnr 4e+01
# Epoch 3327:
# Epoch 3327, train_cost 0.084, psnr 4e+01
# Epoch 3328:
# Epoch 3328, train_cost 0.081, psnr 4e+01
# Epoch 3329:
# Epoch 3329, train_cost 0.083, psnr 4e+01
# Epoch 3330:
# Epoch 3330, train_cost 0.083, psnr 4e+01
# Epoch 3331:
# Epoch 3331, train_cost 0.081, psnr 4e+01
# Epoch 3332:
# Epoch 3332, train_cost 0.082, psnr 4e+01
# Epoch 3333:
# Epoch 3333, train_cost 0.081, psnr 4e+01
# Epoch 3334:
# Epoch 3334, train_cost 0.081, psnr 4e+01
# Epoch 3335:
# Epoch 3335, train_cost 0.083, psnr 4e+01
# Epoch 3336:
# Epoch 3336, train_cost 0.082, psnr 4e+01
# Epoch 3337:
# Epoch 3337, train_cost 0.081, psnr 4e+01
# Epoch 3338:
# Epoch 3338, train_cost 0.081, psnr 4e+01
# Epoch 3339:
# Epoch 3339, train_cost 0.085, psnr 4e+01
# Epoch 3340:
# Epoch 3340, train_cost 0.082, psnr 4e+01
# Epoch 3341:
# Epoch 3341, train_cost 0.082, psnr 4e+01
# Epoch 3342:
# Epoch 3342, train_cost 0.083, psnr 4e+01
# Epoch 3343:
# Epoch 3343, train_cost 0.08, psnr 4.1e+01
# Epoch 3344:
# Epoch 3344, train_cost 0.08, psnr 4e+01
# Epoch 3345:
# Epoch 3345, train_cost 0.082, psnr 4e+01
# Epoch 3346:
# Epoch 3346, train_cost 0.081, psnr 4e+01
# Epoch 3347:
# Epoch 3347, train_cost 0.085, psnr 4e+01
# Epoch 3348:
# Epoch 3348, train_cost 0.085, psnr 4e+01
# Epoch 3349:
# Epoch 3349, train_cost 0.082, psnr 4e+01
# Epoch 3350:
# Epoch 3350, train_cost 0.084, psnr 4e+01
# Epoch 3351:
# Epoch 3351, train_cost 0.083, psnr 4e+01
# Epoch 3352:
# Epoch 3352, train_cost 0.082, psnr 4e+01
# Epoch 3353:
# Epoch 3353, train_cost 0.083, psnr 4e+01
# Epoch 3354:
# Epoch 3354, train_cost 0.082, psnr 4e+01
# Epoch 3355:
# Epoch 3355, train_cost 0.082, psnr 4e+01
# Epoch 3356:
# Epoch 3356, train_cost 0.084, psnr 4e+01
# Epoch 3357:
# Epoch 3357, train_cost 0.082, psnr 4e+01
# Epoch 3358:
# Epoch 3358, train_cost 0.084, psnr 4e+01
# Epoch 3359:
# Epoch 3359, train_cost 0.082, psnr 4e+01
# Epoch 3360:
# Epoch 3360, train_cost 0.083, psnr 4e+01
# Epoch 3361:
# Epoch 3361, train_cost 0.084, psnr 4e+01
# Epoch 3362:
# Epoch 3362, train_cost 0.083, psnr 4e+01
# Epoch 3363:
# Epoch 3363, train_cost 0.082, psnr 4e+01
# Epoch 3364:
# Epoch 3364, train_cost 0.082, psnr 4e+01
# Epoch 3365:
# Epoch 3365, train_cost 0.084, psnr 4e+01
# Epoch 3366:
# Epoch 3366, train_cost 0.08, psnr 4.1e+01
# Epoch 3367:
# Epoch 3367, train_cost 0.082, psnr 4.1e+01
# Epoch 3368:
# Epoch 3368, train_cost 0.081, psnr 4e+01
# Epoch 3369:
# Epoch 3369, train_cost 0.082, psnr 4e+01
# Epoch 3370:
# Epoch 3370, train_cost 0.085, psnr 4e+01
# Epoch 3371:
# Epoch 3371, train_cost 0.082, psnr 4e+01
# Epoch 3372:
# Epoch 3372, train_cost 0.082, psnr 4e+01
# Epoch 3373:
# Epoch 3373, train_cost 0.082, psnr 4e+01
# Epoch 3374:
# Epoch 3374, train_cost 0.083, psnr 4e+01
# Epoch 3375:
# Epoch 3375, train_cost 0.084, psnr 4e+01
# Epoch 3376:
# Epoch 3376, train_cost 0.08, psnr 4e+01
# Epoch 3377:
# Epoch 3377, train_cost 0.083, psnr 4e+01
# Epoch 3378:
# Epoch 3378, train_cost 0.085, psnr 4e+01
# Epoch 3379:
# Epoch 3379, train_cost 0.081, psnr 4e+01
# Epoch 3380:
# Epoch 3380, train_cost 0.082, psnr 4e+01
# Epoch 3381:
# Epoch 3381, train_cost 0.082, psnr 4e+01
# Epoch 3382:
# Epoch 3382, train_cost 0.082, psnr 4e+01
# Epoch 3383:
# Epoch 3383, train_cost 0.082, psnr 4e+01
# Epoch 3384:
# Epoch 3384, train_cost 0.08, psnr 4.1e+01
# Epoch 3385:
# Epoch 3385, train_cost 0.082, psnr 4e+01
# Epoch 3386:
# Epoch 3386, train_cost 0.082, psnr 4e+01
# Epoch 3387:
# Epoch 3387, train_cost 0.083, psnr 4e+01
# Epoch 3388:
# Epoch 3388, train_cost 0.081, psnr 4e+01
# Epoch 3389:
# Epoch 3389, train_cost 0.084, psnr 4e+01
# Epoch 3390:
# Epoch 3390, train_cost 0.082, psnr 4e+01
# Epoch 3391:
# Epoch 3391, train_cost 0.085, psnr 4e+01
# Epoch 3392:
# Epoch 3392, train_cost 0.081, psnr 4e+01
# Epoch 3393:
# Epoch 3393, train_cost 0.085, psnr 4e+01
# Epoch 3394:
# Epoch 3394, train_cost 0.082, psnr 4e+01
# Epoch 3395:
# Epoch 3395, train_cost 0.081, psnr 4.1e+01
# Epoch 3396:
# Epoch 3396, train_cost 0.083, psnr 4e+01
# Epoch 3397:
# Epoch 3397, train_cost 0.082, psnr 4e+01
# Epoch 3398:
# Epoch 3398, train_cost 0.08, psnr 4.1e+01
# Epoch 3399:
# Epoch 3399, train_cost 0.082, psnr 4e+01
# Epoch 3400:
# Epoch 3400, train_cost 0.083, psnr 4e+01
# Epoch 3401:
# Epoch 3401, train_cost 0.081, psnr 4e+01
# Epoch 3402:
# Epoch 3402, train_cost 0.082, psnr 4e+01
# Epoch 3403:
# Epoch 3403, train_cost 0.084, psnr 4e+01
# Epoch 3404:
# Epoch 3404, train_cost 0.083, psnr 4e+01
# Epoch 3405:
# Epoch 3405, train_cost 0.083, psnr 4e+01
# Epoch 3406:
# Epoch 3406, train_cost 0.084, psnr 4e+01
# Epoch 3407:
# Epoch 3407, train_cost 0.083, psnr 4e+01
# Epoch 3408:
# Epoch 3408, train_cost 0.082, psnr 4e+01
# Epoch 3409:
# Epoch 3409, train_cost 0.082, psnr 4e+01
# Epoch 3410:
# Epoch 3410, train_cost 0.085, psnr 4e+01
# Epoch 3411:
# Epoch 3411, train_cost 0.082, psnr 4e+01
# Epoch 3412:
# Epoch 3412, train_cost 0.082, psnr 4e+01
# Epoch 3413:
# Epoch 3413, train_cost 0.084, psnr 4e+01
# Epoch 3414:
# Epoch 3414, train_cost 0.081, psnr 4.1e+01
# Epoch 3415:
# Epoch 3415, train_cost 0.082, psnr 4e+01
# Epoch 3416:
# Epoch 3416, train_cost 0.082, psnr 4e+01
# Epoch 3417:
# Epoch 3417, train_cost 0.083, psnr 4e+01
# Epoch 3418:
# Epoch 3418, train_cost 0.082, psnr 4e+01
# Epoch 3419:
# Epoch 3419, train_cost 0.085, psnr 4e+01
# Epoch 3420:
# Epoch 3420, train_cost 0.082, psnr 4e+01
# Epoch 3421:
# Epoch 3421, train_cost 0.082, psnr 4e+01
# Epoch 3422:
# Epoch 3422, train_cost 0.083, psnr 4e+01
# Epoch 3423:
# Epoch 3423, train_cost 0.081, psnr 4e+01
# Epoch 3424:
# Epoch 3424, train_cost 0.082, psnr 4e+01
# Epoch 3425:
# Epoch 3425, train_cost 0.082, psnr 4e+01
# Epoch 3426:
# Epoch 3426, train_cost 0.081, psnr 4e+01
# Epoch 3427:
# Epoch 3427, train_cost 0.08, psnr 4.1e+01
# Epoch 3428:
# Epoch 3428, train_cost 0.083, psnr 4e+01
# Epoch 3429:
# Epoch 3429, train_cost 0.081, psnr 4e+01
# Epoch 3430:
# Epoch 3430, train_cost 0.084, psnr 4e+01
# Epoch 3431:
# Epoch 3431, train_cost 0.083, psnr 4e+01
# Epoch 3432:
# Epoch 3432, train_cost 0.081, psnr 4e+01
# Epoch 3433:
# Epoch 3433, train_cost 0.084, psnr 4e+01
# Epoch 3434:
# Epoch 3434, train_cost 0.083, psnr 4e+01
# Epoch 3435:
# Epoch 3435, train_cost 0.083, psnr 4e+01
# Epoch 3436:
# Epoch 3436, train_cost 0.083, psnr 4e+01
# Epoch 3437:
# Epoch 3437, train_cost 0.081, psnr 4e+01
# Epoch 3438:
# Epoch 3438, train_cost 0.08, psnr 4.1e+01
# Epoch 3439:
# Epoch 3439, train_cost 0.081, psnr 4e+01
# Epoch 3440:
# Epoch 3440, train_cost 0.082, psnr 4e+01
# Epoch 3441:
# Epoch 3441, train_cost 0.082, psnr 4e+01
# Epoch 3442:
# Epoch 3442, train_cost 0.084, psnr 4e+01
# Epoch 3443:
# Epoch 3443, train_cost 0.081, psnr 4e+01
# Epoch 3444:
# Epoch 3444, train_cost 0.081, psnr 4e+01
# Epoch 3445:
# Epoch 3445, train_cost 0.084, psnr 4e+01
# Epoch 3446:
# Epoch 3446, train_cost 0.082, psnr 4e+01
# Epoch 3447:
# Epoch 3447, train_cost 0.083, psnr 4e+01
# Epoch 3448:
# Epoch 3448, train_cost 0.081, psnr 4e+01
# Epoch 3449:
# Epoch 3449, train_cost 0.082, psnr 4e+01
# Epoch 3450:
# Epoch 3450, train_cost 0.082, psnr 4e+01
# Epoch 3451:
# Epoch 3451, train_cost 0.084, psnr 4e+01
# Epoch 3452:
# Epoch 3452, train_cost 0.082, psnr 4e+01
# Epoch 3453:
# Epoch 3453, train_cost 0.083, psnr 4e+01
# Epoch 3454:
# Epoch 3454, train_cost 0.08, psnr 4.1e+01
# Epoch 3455:
# Epoch 3455, train_cost 0.081, psnr 4e+01
# Epoch 3456:
# Epoch 3456, train_cost 0.083, psnr 4e+01
# Epoch 3457:
# Epoch 3457, train_cost 0.084, psnr 4e+01
# Epoch 3458:
# Epoch 3458, train_cost 0.081, psnr 4e+01
# Epoch 3459:
# Epoch 3459, train_cost 0.084, psnr 4e+01
# Epoch 3460:
# Epoch 3460, train_cost 0.082, psnr 4e+01
# Epoch 3461:
# Epoch 3461, train_cost 0.081, psnr 4e+01
# Epoch 3462:
# Epoch 3462, train_cost 0.082, psnr 4e+01
# Epoch 3463:
# Epoch 3463, train_cost 0.081, psnr 4.1e+01
# Epoch 3464:
# Epoch 3464, train_cost 0.083, psnr 4e+01
# Epoch 3465:
# Epoch 3465, train_cost 0.083, psnr 4e+01
# Epoch 3466:
# Epoch 3466, train_cost 0.081, psnr 4e+01
# Epoch 3467:
# Epoch 3467, train_cost 0.084, psnr 4e+01
# Epoch 3468:
# Epoch 3468, train_cost 0.084, psnr 4e+01
# Epoch 3469:
# Epoch 3469, train_cost 0.081, psnr 4e+01
# Epoch 3470:
# Epoch 3470, train_cost 0.081, psnr 4e+01
# Epoch 3471:
# Epoch 3471, train_cost 0.083, psnr 4e+01
# Epoch 3472:
# Epoch 3472, train_cost 0.082, psnr 4e+01
# Epoch 3473:
# Epoch 3473, train_cost 0.083, psnr 4e+01
# Epoch 3474:
# Epoch 3474, train_cost 0.083, psnr 4e+01
# Epoch 3475:
# Epoch 3475, train_cost 0.081, psnr 4e+01
# Epoch 3476:
# Epoch 3476, train_cost 0.081, psnr 4e+01
# Epoch 3477:
# Epoch 3477, train_cost 0.082, psnr 4e+01
# Epoch 3478:
# Epoch 3478, train_cost 0.083, psnr 4e+01
# Epoch 3479:
# Epoch 3479, train_cost 0.082, psnr 4e+01
# Epoch 3480:
# Epoch 3480, train_cost 0.083, psnr 4e+01
# Epoch 3481:
# Epoch 3481, train_cost 0.081, psnr 4.1e+01
# Epoch 3482:
# Epoch 3482, train_cost 0.084, psnr 4e+01
# Epoch 3483:
# Epoch 3483, train_cost 0.082, psnr 4e+01
# Epoch 3484:
# Epoch 3484, train_cost 0.083, psnr 4e+01
# Epoch 3485:
# Epoch 3485, train_cost 0.082, psnr 4e+01
# Epoch 3486:
# Epoch 3486, train_cost 0.083, psnr 4e+01
# Epoch 3487:
# Epoch 3487, train_cost 0.083, psnr 4e+01
# Epoch 3488:
# Epoch 3488, train_cost 0.081, psnr 4e+01
# Epoch 3489:
# Epoch 3489, train_cost 0.082, psnr 4e+01
# Epoch 3490:
# Epoch 3490, train_cost 0.081, psnr 4.1e+01
# Epoch 3491:
# Epoch 3491, train_cost 0.083, psnr 4e+01
# Epoch 3492:
# Epoch 3492, train_cost 0.08, psnr 4e+01
# Epoch 3493:
# Epoch 3493, train_cost 0.084, psnr 4e+01
# Epoch 3494:
# Epoch 3494, train_cost 0.083, psnr 4e+01
# Epoch 3495:
# Epoch 3495, train_cost 0.082, psnr 4e+01
# Epoch 3496:
# Epoch 3496, train_cost 0.085, psnr 4e+01
# Epoch 3497:
# Epoch 3497, train_cost 0.085, psnr 4e+01
# Epoch 3498:
# Epoch 3498, train_cost 0.083, psnr 4e+01
# Epoch 3499:
# Epoch 3499, train_cost 0.081, psnr 4e+01
# Epoch 3500:
# Epoch 3500, train_cost 0.082, psnr 4e+01
# Epoch 3501:
# Epoch 3501, train_cost 0.083, psnr 4e+01
# Epoch 3502:
# Epoch 3502, train_cost 0.083, psnr 4e+01
# Epoch 3503:
# Epoch 3503, train_cost 0.083, psnr 4e+01
# Epoch 3504:
# Epoch 3504, train_cost 0.081, psnr 4.1e+01
# Epoch 3505:
# Epoch 3505, train_cost 0.082, psnr 4e+01
# Epoch 3506:
# Epoch 3506, train_cost 0.082, psnr 4e+01
# Epoch 3507:
# Epoch 3507, train_cost 0.082, psnr 4e+01
# Epoch 3508:
# Epoch 3508, train_cost 0.083, psnr 4e+01
# Epoch 3509:
# Epoch 3509, train_cost 0.082, psnr 4e+01
# Epoch 3510:
# Epoch 3510, train_cost 0.085, psnr 4e+01
# Epoch 3511:
# Epoch 3511, train_cost 0.081, psnr 4e+01
# Epoch 3512:
# Epoch 3512, train_cost 0.084, psnr 4e+01
# Epoch 3513:
# Epoch 3513, train_cost 0.082, psnr 4e+01
# Epoch 3514:
# Epoch 3514, train_cost 0.084, psnr 4e+01
# Epoch 3515:
# Epoch 3515, train_cost 0.083, psnr 4e+01
# Epoch 3516:
# Epoch 3516, train_cost 0.083, psnr 4e+01
# Epoch 3517:
# Epoch 3517, train_cost 0.082, psnr 4e+01
# Epoch 3518:
# Epoch 3518, train_cost 0.081, psnr 4e+01
# Epoch 3519:
# Epoch 3519, train_cost 0.081, psnr 4e+01
# Epoch 3520:
# Epoch 3520, train_cost 0.083, psnr 4e+01
# Epoch 3521:
# Epoch 3521, train_cost 0.082, psnr 4e+01
# Epoch 3522:
# Epoch 3522, train_cost 0.084, psnr 4e+01
# Epoch 3523:
# Epoch 3523, train_cost 0.081, psnr 4e+01
# Epoch 3524:
# Epoch 3524, train_cost 0.083, psnr 4e+01
# Epoch 3525:
# Epoch 3525, train_cost 0.083, psnr 4e+01
# Epoch 3526:
# Epoch 3526, train_cost 0.082, psnr 4e+01
# Epoch 3527:
# Epoch 3527, train_cost 0.083, psnr 4e+01
# Epoch 3528:
# Epoch 3528, train_cost 0.081, psnr 4e+01
# Epoch 3529:
# Epoch 3529, train_cost 0.082, psnr 4e+01
# Epoch 3530:
# Epoch 3530, train_cost 0.083, psnr 4e+01
# Epoch 3531:
# Epoch 3531, train_cost 0.084, psnr 4e+01
# Epoch 3532:
# Epoch 3532, train_cost 0.084, psnr 4e+01
# Epoch 3533:
# Epoch 3533, train_cost 0.082, psnr 4e+01
# Epoch 3534:
# Epoch 3534, train_cost 0.085, psnr 4e+01
# Epoch 3535:
# Epoch 3535, train_cost 0.084, psnr 4e+01
# Epoch 3536:
# Epoch 3536, train_cost 0.081, psnr 4e+01
# Epoch 3537:
# Epoch 3537, train_cost 0.083, psnr 4e+01
# Epoch 3538:
# Epoch 3538, train_cost 0.08, psnr 4.1e+01
# Epoch 3539:
# Epoch 3539, train_cost 0.084, psnr 4e+01
# Epoch 3540:
# Epoch 3540, train_cost 0.082, psnr 4e+01
# Epoch 3541:
# Epoch 3541, train_cost 0.08, psnr 4.1e+01
# Epoch 3542:
# Epoch 3542, train_cost 0.081, psnr 4e+01
# Epoch 3543:
# Epoch 3543, train_cost 0.082, psnr 4e+01
# Epoch 3544:
# Epoch 3544, train_cost 0.085, psnr 4e+01
# Epoch 3545:
# Epoch 3545, train_cost 0.082, psnr 4e+01
# Epoch 3546:
# Epoch 3546, train_cost 0.081, psnr 4e+01
# Epoch 3547:
# Epoch 3547, train_cost 0.083, psnr 4e+01
# Epoch 3548:
# Epoch 3548, train_cost 0.081, psnr 4e+01
# Epoch 3549:
# Epoch 3549, train_cost 0.083, psnr 4e+01
# Epoch 3550:
# Epoch 3550, train_cost 0.08, psnr 4.1e+01
# Epoch 3551:
# Epoch 3551, train_cost 0.082, psnr 4e+01
# Epoch 3552:
# Epoch 3552, train_cost 0.084, psnr 4e+01
# Epoch 3553:
# Epoch 3553, train_cost 0.082, psnr 4e+01
# Epoch 3554:
# Epoch 3554, train_cost 0.082, psnr 4e+01
# Epoch 3555:
# Epoch 3555, train_cost 0.082, psnr 4e+01
# Epoch 3556:
# Epoch 3556, train_cost 0.086, psnr 4e+01
# Epoch 3557:
# Epoch 3557, train_cost 0.082, psnr 4e+01
# Epoch 3558:
# Epoch 3558, train_cost 0.08, psnr 4.1e+01
# Epoch 3559:
# Epoch 3559, train_cost 0.082, psnr 4e+01
# Epoch 3560:
# Epoch 3560, train_cost 0.081, psnr 4e+01
# Epoch 3561:
# Epoch 3561, train_cost 0.081, psnr 4e+01
# Epoch 3562:
# Epoch 3562, train_cost 0.083, psnr 4e+01
# Epoch 3563:
# Epoch 3563, train_cost 0.083, psnr 4e+01
# Epoch 3564:
# Epoch 3564, train_cost 0.081, psnr 4e+01
# Epoch 3565:
# Epoch 3565, train_cost 0.083, psnr 4e+01
# Epoch 3566:
# Epoch 3566, train_cost 0.083, psnr 4e+01
# Epoch 3567:
# Epoch 3567, train_cost 0.082, psnr 4e+01
# Epoch 3568:
# Epoch 3568, train_cost 0.083, psnr 4e+01
# Epoch 3569:
# Epoch 3569, train_cost 0.081, psnr 4e+01
# Epoch 3570:
# Epoch 3570, train_cost 0.085, psnr 4e+01
# Epoch 3571:
# Epoch 3571, train_cost 0.084, psnr 4e+01
# Epoch 3572:
# Epoch 3572, train_cost 0.085, psnr 4e+01
# Epoch 3573:
# Epoch 3573, train_cost 0.081, psnr 4e+01
# Epoch 3574:
# Epoch 3574, train_cost 0.082, psnr 4e+01
# Epoch 3575:
# Epoch 3575, train_cost 0.082, psnr 4e+01
# Epoch 3576:
# Epoch 3576, train_cost 0.082, psnr 4e+01
# Epoch 3577:
# Epoch 3577, train_cost 0.08, psnr 4.1e+01
# Epoch 3578:
# Epoch 3578, train_cost 0.083, psnr 4e+01
# Epoch 3579:
# Epoch 3579, train_cost 0.084, psnr 4e+01
# Epoch 3580:
# Epoch 3580, train_cost 0.081, psnr 4e+01
# Epoch 3581:
# Epoch 3581, train_cost 0.085, psnr 4e+01
# Epoch 3582:
# Epoch 3582, train_cost 0.08, psnr 4.1e+01
# Epoch 3583:
# Epoch 3583, train_cost 0.082, psnr 4e+01
# Epoch 3584:
# Epoch 3584, train_cost 0.084, psnr 4e+01
# Epoch 3585:
# Epoch 3585, train_cost 0.084, psnr 4e+01
# Epoch 3586:
# Epoch 3586, train_cost 0.083, psnr 4e+01
# Epoch 3587:
# Epoch 3587, train_cost 0.081, psnr 4e+01
# Epoch 3588:
# Epoch 3588, train_cost 0.084, psnr 4e+01
# Epoch 3589:
# Epoch 3589, train_cost 0.083, psnr 4e+01
# Epoch 3590:
# Epoch 3590, train_cost 0.085, psnr 4e+01
# Epoch 3591:
# Epoch 3591, train_cost 0.08, psnr 4.1e+01
# Epoch 3592:
# Epoch 3592, train_cost 0.082, psnr 4e+01
# Epoch 3593:
# Epoch 3593, train_cost 0.082, psnr 4e+01
# Epoch 3594:
# Epoch 3594, train_cost 0.082, psnr 4e+01
# Epoch 3595:
# Epoch 3595, train_cost 0.081, psnr 4e+01
# Epoch 3596:
# Epoch 3596, train_cost 0.081, psnr 4e+01
# Epoch 3597:
# Epoch 3597, train_cost 0.084, psnr 4e+01
# Epoch 3598:
# Epoch 3598, train_cost 0.082, psnr 4e+01
# Epoch 3599:
# Epoch 3599, train_cost 0.082, psnr 4e+01
# Epoch 3600:
# Epoch 3600, train_cost 0.082, psnr 4e+01
# Epoch 3601:
# Epoch 3601, train_cost 0.081, psnr 4e+01
# Epoch 3602:
# Epoch 3602, train_cost 0.083, psnr 4e+01
# Epoch 3603:
# Epoch 3603, train_cost 0.082, psnr 4e+01
# Epoch 3604:
# Epoch 3604, train_cost 0.081, psnr 4.1e+01
# Epoch 3605:
# Epoch 3605, train_cost 0.081, psnr 4.1e+01
# Epoch 3606:
# Epoch 3606, train_cost 0.083, psnr 4e+01
# Epoch 3607:
# Epoch 3607, train_cost 0.081, psnr 4e+01
# Epoch 3608:
# Epoch 3608, train_cost 0.083, psnr 4e+01
# Epoch 3609:
# Epoch 3609, train_cost 0.083, psnr 4e+01
# Epoch 3610:
# Epoch 3610, train_cost 0.084, psnr 4e+01
# Epoch 3611:
# Epoch 3611, train_cost 0.082, psnr 4e+01
# Epoch 3612:
# Epoch 3612, train_cost 0.082, psnr 4e+01
# Epoch 3613:
# Epoch 3613, train_cost 0.081, psnr 4e+01
# Epoch 3614:
# Epoch 3614, train_cost 0.082, psnr 4e+01
# Epoch 3615:
# Epoch 3615, train_cost 0.08, psnr 4.1e+01
# Epoch 3616:
# Epoch 3616, train_cost 0.081, psnr 4e+01
# Epoch 3617:
# Epoch 3617, train_cost 0.081, psnr 4e+01
# Epoch 3618:
# Epoch 3618, train_cost 0.083, psnr 4e+01
# Epoch 3619:
# Epoch 3619, train_cost 0.083, psnr 4e+01
# Epoch 3620:
# Epoch 3620, train_cost 0.081, psnr 4.1e+01
# Epoch 3621:
# Epoch 3621, train_cost 0.083, psnr 4e+01
# Epoch 3622:
# Epoch 3622, train_cost 0.082, psnr 4e+01
# Epoch 3623:
# Epoch 3623, train_cost 0.082, psnr 4e+01
# Epoch 3624:
# Epoch 3624, train_cost 0.082, psnr 4e+01
# Epoch 3625:
# Epoch 3625, train_cost 0.082, psnr 4e+01
# Epoch 3626:
# Epoch 3626, train_cost 0.082, psnr 4e+01
# Epoch 3627:
# Epoch 3627, train_cost 0.082, psnr 4e+01
# Epoch 3628:
# Epoch 3628, train_cost 0.081, psnr 4.1e+01
# Epoch 3629:
# Epoch 3629, train_cost 0.08, psnr 4.1e+01
# Epoch 3630:
# Epoch 3630, train_cost 0.083, psnr 4e+01
# Epoch 3631:
# Epoch 3631, train_cost 0.08, psnr 4e+01
# Epoch 3632:
# Epoch 3632, train_cost 0.083, psnr 4e+01
# Epoch 3633:
# Epoch 3633, train_cost 0.083, psnr 4e+01
# Epoch 3634:
# Epoch 3634, train_cost 0.081, psnr 4.1e+01
# Epoch 3635:
# Epoch 3635, train_cost 0.081, psnr 4e+01
# Epoch 3636:
# Epoch 3636, train_cost 0.083, psnr 4e+01
# Epoch 3637:
# Epoch 3637, train_cost 0.082, psnr 4e+01
# Epoch 3638:
# Epoch 3638, train_cost 0.082, psnr 4e+01
# Epoch 3639:
# Epoch 3639, train_cost 0.082, psnr 4e+01
# Epoch 3640:
# Epoch 3640, train_cost 0.082, psnr 4e+01
# Epoch 3641:
# Epoch 3641, train_cost 0.081, psnr 4e+01
# Epoch 3642:
# Epoch 3642, train_cost 0.082, psnr 4e+01
# Epoch 3643:
# Epoch 3643, train_cost 0.083, psnr 4e+01
# Epoch 3644:
# Epoch 3644, train_cost 0.081, psnr 4.1e+01
# Epoch 3645:
# Epoch 3645, train_cost 0.084, psnr 4e+01
# Epoch 3646:
# Epoch 3646, train_cost 0.083, psnr 4e+01
# Epoch 3647:
# Epoch 3647, train_cost 0.081, psnr 4e+01
# Epoch 3648:
# Epoch 3648, train_cost 0.082, psnr 4e+01
# Epoch 3649:
# Epoch 3649, train_cost 0.082, psnr 4e+01
# Epoch 3650:
# Epoch 3650, train_cost 0.08, psnr 4.1e+01
# Epoch 3651:
# Epoch 3651, train_cost 0.084, psnr 4e+01
# Epoch 3652:
# Epoch 3652, train_cost 0.085, psnr 4e+01
# Epoch 3653:
# Epoch 3653, train_cost 0.081, psnr 4e+01
# Epoch 3654:
# Epoch 3654, train_cost 0.081, psnr 4e+01
# Epoch 3655:
# Epoch 3655, train_cost 0.082, psnr 4e+01
# Epoch 3656:
# Epoch 3656, train_cost 0.083, psnr 4e+01
# Epoch 3657:
# Epoch 3657, train_cost 0.084, psnr 4e+01
# Epoch 3658:
# Epoch 3658, train_cost 0.083, psnr 4e+01
# Epoch 3659:
# Epoch 3659, train_cost 0.083, psnr 4e+01
# Epoch 3660:
# Epoch 3660, train_cost 0.081, psnr 4.1e+01
# Epoch 3661:
# Epoch 3661, train_cost 0.081, psnr 4e+01
# Epoch 3662:
# Epoch 3662, train_cost 0.084, psnr 4e+01
# Epoch 3663:
# Epoch 3663, train_cost 0.083, psnr 4e+01
# Epoch 3664:
# Epoch 3664, train_cost 0.081, psnr 4e+01
# Epoch 3665:
# Epoch 3665, train_cost 0.085, psnr 4e+01
# Epoch 3666:
# Epoch 3666, train_cost 0.082, psnr 4e+01
# Epoch 3667:
# Epoch 3667, train_cost 0.083, psnr 4e+01
# Epoch 3668:
# Epoch 3668, train_cost 0.081, psnr 4.1e+01
# Epoch 3669:
# Epoch 3669, train_cost 0.083, psnr 4e+01
# Epoch 3670:
# Epoch 3670, train_cost 0.082, psnr 4e+01
# Epoch 3671:
# Epoch 3671, train_cost 0.085, psnr 4e+01
# Epoch 3672:
# Epoch 3672, train_cost 0.081, psnr 4e+01
# Epoch 3673:
# Epoch 3673, train_cost 0.085, psnr 4e+01
# Epoch 3674:
# Epoch 3674, train_cost 0.081, psnr 4e+01
# Epoch 3675:
# Epoch 3675, train_cost 0.084, psnr 4e+01
# Epoch 3676:
# Epoch 3676, train_cost 0.083, psnr 4e+01
# Epoch 3677:
# Epoch 3677, train_cost 0.082, psnr 4e+01
# Epoch 3678:
# Epoch 3678, train_cost 0.082, psnr 4e+01
# Epoch 3679:
# Epoch 3679, train_cost 0.084, psnr 4e+01
# Epoch 3680:
# Epoch 3680, train_cost 0.082, psnr 4e+01
# Epoch 3681:
# Epoch 3681, train_cost 0.082, psnr 4e+01
# Epoch 3682:
# Epoch 3682, train_cost 0.084, psnr 4e+01
# Epoch 3683:
# Epoch 3683, train_cost 0.084, psnr 4e+01
# Epoch 3684:
# Epoch 3684, train_cost 0.082, psnr 4e+01
# Epoch 3685:
# Epoch 3685, train_cost 0.082, psnr 4e+01
# Epoch 3686:
# Epoch 3686, train_cost 0.083, psnr 4e+01
# Epoch 3687:
# Epoch 3687, train_cost 0.082, psnr 4e+01
# Epoch 3688:
# Epoch 3688, train_cost 0.082, psnr 4e+01
# Epoch 3689:
# Epoch 3689, train_cost 0.082, psnr 4e+01
# Epoch 3690:
# Epoch 3690, train_cost 0.084, psnr 4e+01
# Epoch 3691:
# Epoch 3691, train_cost 0.083, psnr 4e+01
# Epoch 3692:
# Epoch 3692, train_cost 0.083, psnr 4e+01
# Epoch 3693:
# Epoch 3693, train_cost 0.083, psnr 4e+01
# Epoch 3694:
# Epoch 3694, train_cost 0.08, psnr 4.1e+01
# Epoch 3695:
# Epoch 3695, train_cost 0.084, psnr 4e+01
# Epoch 3696:
# Epoch 3696, train_cost 0.084, psnr 4e+01
# Epoch 3697:
# Epoch 3697, train_cost 0.083, psnr 4e+01
# Epoch 3698:
# Epoch 3698, train_cost 0.083, psnr 4e+01
# Epoch 3699:
# ...
# Epoch 4016:
# Epoch 4016, train_cost 0.083, psnr 4e+01
# Epoch 4017:
# Epoch 4017, train_cost 0.079, psnr 4.1e+01
# Epoch 4018:
# Epoch 4018, train_cost 0.082, psnr 4e+01
# Epoch 4019:
# Epoch 4019, train_cost 0.081, psnr 4e+01
# Epoch 4020:
# Epoch 4020, train_cost 0.081, psnr 4e+01
# Epoch 4021:
# Epoch 4021, train_cost 0.084, psnr 4e+01
# Epoch 4022:
# Epoch 4022, train_cost 0.081, psnr 4.1e+01
# Epoch 4023:
# Epoch 4023, train_cost 0.082, psnr 4e+01
# Epoch 4024:
# Epoch 4024, train_cost 0.081, psnr 4.1e+01
# Epoch 4025:
# Epoch 4025, train_cost 0.082, psnr 4e+01
# Epoch 4026:
# Epoch 4026, train_cost 0.081, psnr 4e+01
# Epoch 4151, train_cost 0.082, psnr 4e+01
# Epoch 4152:
# Epoch 4152, train_cost 0.081, psnr 4e+01
# Epoch 4153:
# Epoch 4153, train_cost 0.082, psnr 4e+01
# Epoch 4154:
# Epoch 4154, train_cost 0.082, psnr 4e+01
# Epoch 4155:
# Epoch 4155, train_cost 0.082, psnr 4e+01
# Epoch 4156:
# Epoch 4156, train_cost 0.084, psnr 4e+01
# Epoch 4157:
# Epoch 4157, train_cost 0.081, psnr 4e+01
# Epoch 4158:
# Epoch 4158, train_cost 0.081, psnr 4e+01
# Epoch 4159:
# Epoch 4159, train_cost 0.083, psnr 4e+01
# Epoch 4160:
# Epoch 4160, train_cost 0.081, psnr 4.1e+01
# Epoch 4161:
# Epoch 4161, train_cost 0.085, psnr 4e+01
# Epoch 4162:
# Epoch 4162, train_cost 0.08, psnr 4e+01
# Epoch 4163:
# Epoch 4163, train_cost 0.082, psnr 4e+01
# Epoch 4164:
# Epoch 4164, train_cost 0.082, psnr 4e+01
# Epoch 4165:
# Epoch 4165, train_cost 0.082, psnr 4e+01
# Epoch 4166:
# Epoch 4166, train_cost 0.082, psnr 4e+01
# Epoch 4167:
# Epoch 4167, train_cost 0.082, psnr 4e+01
# Epoch 4168:
# Epoch 4168, train_cost 0.082, psnr 4e+01
# Epoch 4169:
# Epoch 4169, train_cost 0.081, psnr 4e+01
# Epoch 4170:
# Epoch 4170, train_cost 0.081, psnr 4e+01
# Epoch 4171:
# Epoch 4171, train_cost 0.081, psnr 4e+01
# Epoch 4172:
# Epoch 4172, train_cost 0.083, psnr 4e+01
# Epoch 4173:
# Epoch 4173, train_cost 0.081, psnr 4e+01
# Epoch 4174:
# Epoch 4174, train_cost 0.08, psnr 4.1e+01
# Epoch 4175:
# Epoch 4175, train_cost 0.083, psnr 4e+01
# Epoch 4176:
# Epoch 4176, train_cost 0.084, psnr 4e+01
# Epoch 4177:
# Epoch 4177, train_cost 0.083, psnr 4e+01
# Epoch 4178:
# Epoch 4178, train_cost 0.08, psnr 4e+01
# Epoch 4179:
# Epoch 4179, train_cost 0.081, psnr 4e+01
# Epoch 4180:
# Epoch 4180, train_cost 0.083, psnr 4e+01
# Epoch 4181:
# Epoch 4181, train_cost 0.085, psnr 4e+01
# Epoch 4182:
# Epoch 4182, train_cost 0.082, psnr 4e+01
# Epoch 4183:
# Epoch 4183, train_cost 0.084, psnr 4e+01
# Epoch 4184:
# Epoch 4184, train_cost 0.084, psnr 4e+01
# Epoch 4185:
# Epoch 4185, train_cost 0.082, psnr 4e+01
# Epoch 4186:
# Epoch 4186, train_cost 0.081, psnr 4e+01
# Epoch 4187:
# Epoch 4187, train_cost 0.081, psnr 4e+01
# Epoch 4188:
# Epoch 4188, train_cost 0.082, psnr 4e+01
# Epoch 4189:
# Epoch 4189, train_cost 0.079, psnr 4.1e+01
# Epoch 4190:
# Epoch 4190, train_cost 0.083, psnr 4e+01
# Epoch 4191:
# Epoch 4191, train_cost 0.081, psnr 4e+01
# Epoch 4192:
# Epoch 4192, train_cost 0.082, psnr 4e+01
# Epoch 4234, train_cost 0.083, psnr 4e+01
# Epoch 4235:
# Epoch 4235, train_cost 0.081, psnr 4.1e+01
# Epoch 4236:
# Epoch 4236, train_cost 0.082, psnr 4e+01
# Epoch 4237:
# Epoch 4237, train_cost 0.082, psnr 4e+01
# Epoch 4238:
# Epoch 4238, train_cost 0.084, psnr 4e+01
# Epoch 4239:
# Epoch 4239, train_cost 0.082, psnr 4.1e+01
# Epoch 4240:
# Epoch 4240, train_cost 0.083, psnr 4e+01
# Epoch 4241:
# Epoch 4241, train_cost 0.084, psnr 4e+01
# Epoch 4242:
# Epoch 4242, train_cost 0.082, psnr 4e+01
# Epoch 4243:
# Epoch 4243, train_cost 0.082, psnr 4e+01
# Epoch 4244:
# Epoch 4244, train_cost 0.082, psnr 4e+01
# Epoch 4245:
# Epoch 4245, train_cost 0.081, psnr 4e+01
# Epoch 4246:
# Epoch 4246, train_cost 0.081, psnr 4e+01
# Epoch 4247:
# Epoch 4247, train_cost 0.081, psnr 4e+01
# Epoch 4248:
# Epoch 4248, train_cost 0.084, psnr 4e+01
# Epoch 4249:
# Epoch 4249, train_cost 0.083, psnr 4e+01
# Epoch 4250:
# Epoch 4250, train_cost 0.079, psnr 4.1e+01
# Epoch 4251:
# Epoch 4251, train_cost 0.083, psnr 4e+01
# Epoch 4252:
# Epoch 4252, train_cost 0.081, psnr 4e+01
# Epoch 4253:
# Epoch 4253, train_cost 0.084, psnr 4e+01
# Epoch 4254:
# Epoch 4254, train_cost 0.081, psnr 4e+01
# Epoch 4255:
# Epoch 4255, train_cost 0.083, psnr 4e+01
# Epoch 4256:
# Epoch 4256, train_cost 0.081, psnr 4e+01
# Epoch 4257:
# Epoch 4257, train_cost 0.082, psnr 4e+01
# Epoch 4258:
# Epoch 4258, train_cost 0.083, psnr 4e+01
# Epoch 4259:
# Epoch 4259, train_cost 0.081, psnr 4e+01
# Epoch 4260:
# Epoch 4260, train_cost 0.081, psnr 4e+01
# Epoch 4261:
# Epoch 4261, train_cost 0.083, psnr 4e+01
# Epoch 4262:
# Epoch 4262, train_cost 0.081, psnr 4e+01
# Epoch 4263:
# Epoch 4263, train_cost 0.084, psnr 4e+01
# Epoch 4264:
# Epoch 4264, train_cost 0.082, psnr 4e+01
# Epoch 4265:
# Epoch 4265, train_cost 0.083, psnr 4e+01
# Epoch 4266:
# Epoch 4266, train_cost 0.08, psnr 4.1e+01
# Epoch 4267:
# Epoch 4267, train_cost 0.083, psnr 4e+01
# Epoch 4268:
# Epoch 4268, train_cost 0.084, psnr 4e+01
# Epoch 4269:
# Epoch 4269, train_cost 0.083, psnr 4e+01
# Epoch 4270:
# Epoch 4270, train_cost 0.085, psnr 4e+01
# Epoch 4271:
# Epoch 4271, train_cost 0.083, psnr 4e+01
# Epoch 4272:
# Epoch 4272, train_cost 0.08, psnr 4.1e+01
# Epoch 4273:
# Epoch 4273, train_cost 0.083, psnr 4e+01
# Epoch 4274:
# Epoch 4274, train_cost 0.082, psnr 4e+01
# Epoch 4275:
# Epoch 4275, train_cost 0.083, psnr 4e+01
# Epoch 4276:
# Epoch 4276, train_cost 0.084, psnr 4e+01
# Epoch 4277:
# Epoch 4277, train_cost 0.081, psnr 4e+01
# Epoch 4278:
# Epoch 4278, train_cost 0.083, psnr 4e+01
# Epoch 4279:
# Epoch 4279, train_cost 0.081, psnr 4e+01
# Epoch 4280:
# Epoch 4280, train_cost 0.083, psnr 4e+01
# Epoch 4281:
# Epoch 4281, train_cost 0.08, psnr 4e+01
# Epoch 4282:
# Epoch 4282, train_cost 0.08, psnr 4.1e+01
# Epoch 4283:
# Epoch 4283, train_cost 0.082, psnr 4e+01
# Epoch 4284:
# Epoch 4284, train_cost 0.082, psnr 4e+01
# Epoch 4285:
# Epoch 4285, train_cost 0.084, psnr 4e+01
# Epoch 4286:
# Epoch 4286, train_cost 0.082, psnr 4e+01
# Epoch 4287:
# Epoch 4287, train_cost 0.083, psnr 4e+01
# Epoch 4288:
# Epoch 4288, train_cost 0.084, psnr 4e+01
# Epoch 4289:
# Epoch 4289, train_cost 0.082, psnr 4e+01
# Epoch 4290:
# Epoch 4290, train_cost 0.081, psnr 4e+01
# Epoch 4291:
# Epoch 4291, train_cost 0.084, psnr 4e+01
# Epoch 4292:
# Epoch 4292, train_cost 0.081, psnr 4e+01
# Epoch 4293:
# Epoch 4293, train_cost 0.081, psnr 4e+01
# Epoch 4294:
# Epoch 4294, train_cost 0.082, psnr 4e+01
# Epoch 4295:
# Epoch 4295, train_cost 0.082, psnr 4e+01
# Epoch 4296:
# Epoch 4296, train_cost 0.082, psnr 4e+01
# Epoch 4297:
# Epoch 4297, train_cost 0.083, psnr 4e+01
# Epoch 4298:
# Epoch 4298, train_cost 0.082, psnr 4e+01
# Epoch 4299:
# Epoch 4299, train_cost 0.081, psnr 4e+01
# Epoch 4300:
# Epoch 4300, train_cost 0.083, psnr 4e+01
# Epoch 4301:
# Epoch 4301, train_cost 0.082, psnr 4e+01
# Epoch 4302:
# Epoch 4302, train_cost 0.083, psnr 4e+01
# Epoch 4303:
# Epoch 4303, train_cost 0.083, psnr 4e+01
# Epoch 4304:
# Epoch 4304, train_cost 0.084, psnr 4e+01
# Epoch 4305:
# Epoch 4305, train_cost 0.083, psnr 4e+01
# Epoch 4306:
# Epoch 4306, train_cost 0.081, psnr 4.1e+01
# Epoch 4307:
# Epoch 4307, train_cost 0.082, psnr 4e+01
# Epoch 4308:
# Epoch 4308, train_cost 0.082, psnr 4e+01
# Epoch 4309:
# Epoch 4309, train_cost 0.084, psnr 4e+01
# Epoch 4310:
# Epoch 4310, train_cost 0.082, psnr 4e+01
# Epoch 4311:
# Epoch 4311, train_cost 0.083, psnr 4e+01
# Epoch 4312:
# Epoch 4312, train_cost 0.084, psnr 4e+01
# Epoch 4313:
# Epoch 4313, train_cost 0.084, psnr 4e+01
# Epoch 4314:
# Epoch 4314, train_cost 0.08, psnr 4.1e+01
# Epoch 4315:
# Epoch 4315, train_cost 0.081, psnr 4e+01
# Epoch 4316:
# Epoch 4316, train_cost 0.081, psnr 4e+01

# %%
from network import img_diff, img_show, img_disp
